# %% [markdown]
# 计划披露日 减持方式	拟减持原因	持股数量

# %%
import pandas as pd

# 读取文件
file_path = "old/data_simulate_08.csv"
data = pd.read_csv(file_path)

# 检查 "公司简称" 是否有重复
duplicates = data['公司简称'].duplicated().any()

if duplicates:
    print("存在重复的公司简称!")
else:
    print("没有重复的公司简称.")
# Out:
# 存在重复的公司简称!

# %%
130+38+176+278+117+50+94+110+120+113
# Out:
# 1226

# %%
(130+38+176+278+117+50+94+110+120+113)*0.7
# Out:
# 858.1999999999999

# %%
130+38+278+117+110+113+120
# Out:
# 906
