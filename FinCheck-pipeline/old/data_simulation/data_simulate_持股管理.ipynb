# %% [markdown]
# # 0. 思路说明

# %% [markdown]
# 为简化计算, 先考虑一个公司一个股东的情况, 有两个需要模拟的方面:
#
# 模拟公司经营情况(财务数据, 被合规处罚情况, )
#
# 模拟股东状态和动作(增持减持, 股东身份, )

# %% [markdown]
# # 1. 部分工具

# %% [markdown]
# ## 1.1 可视化: 减持活动

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import platform
import matplotlib as mpl

def set_chinese_font():
    """
    Configure matplotlib to properly display Chinese characters on both macOS and Windows.
    """
    system = platform.system()
    
    if system == 'Windows':
        font_list = ['SimHei', 'Microsoft YaHei']
    elif system == 'Darwin':  # macOS
        font_list = ['PingFang HK', 'Arial Unicode MS', 'Heiti TC']
    else:  # Linux or other systems
        font_list = ['WenQuanYi Micro Hei', 'Droid Sans Fallback']
    
    # Try different fonts until one works
    for font in font_list:
        try:
            plt.rcParams['font.sans-serif'] = [font]
            # Test if the font works
            mpl.font_manager.findfont(font)

            print(f"检测到当前系统为: {system}, 已为 matplotlib 设置字体: {font}")
            break
        except:
            continue

set_chinese_font()


def plot_timeline(df):
    df = df.copy()
    fig, ax1 = plt.subplots(figsize=(15,6))
    
    # 绘制持股比例曲线
    ax1.plot(df['日期'], df['持股比例'], label='持股比例', color='tab:blue')
    ax1.set_xlabel('日期')
    ax1.set_ylabel('持股比例')
    ax1.grid(True)
    
    # 用颜色标记股东身份
    identity_colors = {
        '持股5%以上股东': 'pink',
        '董监高': 'red',
        '控股股东': 'purple',
        '实际控制人': 'purple',
        # '前控股股东': 'red',
        # '前实际控制人': 'red',
        # '离任董监高': 'blue',
        '普通股东': 'green',
    }
    
    for idx, row in df.iterrows():
        ax1.axvline(row['日期'], color=identity_colors[row['股东身份']], alpha=0.1)
    
    # 标注减持计划区间
    plan_periods = df[df['存在减持计划']].groupby('计划披露日').first()
    for _, plan in plan_periods.iterrows():
        ax1.axvspan(plan['计划开始日'], plan['计划结束日'], alpha=0.3, color='green')
    
    # 获取所有计划披露日并去重
    disclosure_dates = df['计划披露日'].dropna().unique()
    for date in disclosure_dates:
        ax1.axvline(date, color='green', alpha=0.8, label='计划披露日')
    
    # 图例
    legend_elements = [
        Patch(facecolor='green', alpha=0.5, label='减持计划期间'),
        *[Patch(facecolor=c, label=l) for l,c in identity_colors.items()],
        Patch(facecolor='green', edgecolor='green', label='计划披露日')
    ]
    ax1.legend(handles=legend_elements, loc='upper right')
    
    plt.title('股东状态与减持计划时间线')
    plt.show()
# Out:
# 检测到当前系统为: Darwin, 已为 matplotlib 设置字体: PingFang HK

# %% [markdown]
# ## 1.2 可视化: 财务和交易数据

# %%
import matplotlib.pyplot as plt

def draw_financial_and_treading(combined_company_info):

    combined_company_info = combined_company_info.copy()


    # 创建图表
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10), sharex=True)

    # 绘制上面的子图
    # 绘制收盘价和收盘价减每股净资产的折线图
    ax1.plot(combined_company_info['日期'], combined_company_info['收盘价'], label='收盘价', color='blue')
    ax1.plot(combined_company_info['日期'], combined_company_info['收盘价减每股净资产'], label='收盘价减每股净资产', color='green', alpha=0.3)

    # 创建右侧的坐标轴用于绘制日收益率
    ax1_2 = ax1.twinx()
    ax1_2.bar(combined_company_info['日期'], combined_company_info['日收益率'], color='gray', alpha=0.3, label='日收益率')
    ax1_2.set_ylabel('日收益率', color='gray')
    ax1_2.tick_params(axis='y', labelcolor='gray')

    # 在收益率的坐标轴上添加增长率为0的横线
    ax1_2.axhline(0, color='gray', linestyle='--', linewidth=0.8)

    # 设置标签和图例
    ax1.set_ylabel('价格（元）')
    ax1.legend(loc='upper left')
    ax1_2.legend(loc='upper right')

    # 绘制下面的子图
    # 绘制净资产和净利润的折线图
    ax2.plot(combined_company_info['日期'], combined_company_info['净资产'], label='净资产', color='blue')
    ax2.plot(combined_company_info['日期'], combined_company_info['净利润'], label='净利润', color='green')

    # 创建右侧的坐标轴用于绘制净资产增长率和净利润增长率
    ax2_2 = ax2.twinx()
    width = 5  # 设置柱状图的宽度
    ax2_2.bar(combined_company_info['日期'], combined_company_info['净资产增长率'], width=width, alpha=0.1, color='blue', label='净资产增长率')
    ax2_2.bar(combined_company_info['日期'], combined_company_info['净利润增长率'], width=width, alpha=0.1, color='green', label='净利润增长率')
    ax2_2.set_ylabel('增长率', color='red')
    ax2_2.tick_params(axis='y', labelcolor='red')

    # 在增长率的坐标轴上添加增长率为0的横线
    ax2_2.axhline(0, color='gray', linestyle='--', linewidth=0.8)

    # 设置标签和图例
    ax2.set_xlabel('日期')
    ax2.set_ylabel('值')
    ax2.legend(loc='upper left')
    ax2_2.legend(loc='upper right')

    # 添加网格和横线
    ax1.grid(True, which='both', linestyle='--', linewidth=0.5)
    ax2.grid(True, which='both', linestyle='--', linewidth=0.5)
    ax1.axhline(0, color='gray', linewidth=0.8)
    ax2.axhline(0, color='gray', linewidth=0.8)

    # 设置标题
    ax1.set_title('收盘价、收盘价减每股净资产及日收益率')
    ax2.set_title('净资产、净利润及其增长率')

    # 显示图表
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 生成模拟数据

# %% [markdown]
# ## 单个公司单个股东情况

# %% [markdown]
# ### 财务数据

# %%
import pandas as pd
import numpy as np

DEFAULT_FINANCIAL_CONFIG = {
    # 时间范围配置
    "date_range": {
        "start_date": "2020-01-01",
        "end_date": "2024-12-31",
        "freq": "QE-DEC"  # 季度末日期
    },
    
    # 财务初始值配置
    "initial_values": {
        "net_assets": 180_000_000,    # 初始净资产
        "net_profit": 18_000_000,     # 初始净利润
        # "total_shares": 40_000_000,   # 总股本
        "profit_adjustment": -17_000_000  # 净利润调整值
    },
    
    # 增长率配置
    "growth_rates": {
        "net_assets": {"mean": 0.03, "std": 0.09},
        "net_profit": {"mean": 0.05, "std": 0.4}
    },
    
    # 验证条件配置
    "validation": {
        "max_profit_asset_ratio": 0.3,          # 净利润/净资产最大比率
        "max_consecutive_loss_years": 3,        # 最大连续亏损年数
        "max_asset_growth_multiple": 5,         # 净资产最大增长倍数
        "min_loss_quarters": 2                  # 最小亏损季度数
    }
}

class FinancialDataGenerator:
    def __init__(self, config=None):
        self.config = config or DEFAULT_FINANCIAL_CONFIG
        self._process_config()
        
    def _process_config(self):
        """预处理配置参数"""
        # 生成季度日期序列
        date_cfg = self.config["date_range"]
        self.all_quarters = pd.date_range(
            start=date_cfg["start_date"],
            end=date_cfg["end_date"],
            freq=date_cfg["freq"]
        )
        self.num_quarters = len(self.all_quarters)
        
    def generate(self, max_retries=1000):
        """生成符合要求的财务数据"""
        for _ in range(max_retries):
            df = self._generate_base_data()
            df = self._calculate_derived_fields(df)
            if self._validate_data(df):
                return df
        raise ValueError("无法生成符合条件的数据，请调整配置参数")

    def _generate_base_data(self):
        """生成基础数据"""
        growth = self.config["growth_rates"]
        df = pd.DataFrame({
            "日期": self.all_quarters,
            "净资产增长率": np.random.normal(
                growth["net_assets"]["mean"],
                growth["net_assets"]["std"],
                self.num_quarters
            ),
            "净利润增长率": np.random.normal(
                growth["net_profit"]["mean"],
                growth["net_profit"]["std"],
                self.num_quarters
            )
        })
        return df

    def _calculate_derived_fields(self, df):
        """计算衍生字段"""
        init = self.config["initial_values"]
        
        # 计算累积增长率
        df["净资产"] = init["net_assets"] * (1 + df["净资产增长率"]).cumprod()
        df["净利润"] = init["net_profit"] * (1 + df["净利润增长率"]).cumprod()
        
        # 应用调整项
        df["净利润"] += init["profit_adjustment"]

        # 新增资产负债表日列（这是新增的核心代码）
        df["资产负债表日"] = df["日期"].apply(
            lambda dt: dt.replace(day=30) 
            if dt.month in [3, 12] and dt.day == 31 
            else dt
        )

        
        # 计算每股指标
        # df["总股本"] = init["total_shares"]
        # df["每股净资产"] = df["净资产"] / df["总股本"]
        # df["每股净利润"] = df["净利润"] / df["总股本"]
        
        # 公告相关字段
        df["公告类型"] = df["日期"].apply(self._get_report_type)
        df["公告日期"] = df["日期"].apply(self._get_announcement_date)
        
        return df

    def _get_report_type(self, date):
        """确定财务报告类型"""
        fmt_date = date.strftime("%m-%d")
        return {
            "03-31": "季报",
            "06-30": "半年报",
            "09-30": "季报",
            "12-31": "年报"
        }.get(fmt_date, None)

    def _get_announcement_date(self, date):
        """计算公告日期"""
        year = date.year
        month_day = date.strftime("%m-%d")
        
        if month_day == "06-30":
            return pd.Timestamp(f"{year}-08-27")  # 半年报的公告日期: 当年8月27日
        if month_day == "12-31":
            return pd.Timestamp(f"{year+1}-03-30") # 年报的公告日期: 次年3月30日
        if month_day == "03-31":
            return pd.Timestamp(f"{year}-04-30") # (一)季报的公告日期: 当年4月30日
        if month_day == "09-30":
            return pd.Timestamp(f"{year}-10-27") # (三)季报的公告日期: 当年10月27日
        return None

    def _validate_data(self, df):
        """验证数据是否符合业务规则"""
        val_cfg = self.config["validation"]
        
        # 条件1: 净利润/净资产比率限制
        ratio_condition = (df["净利润"] / df["净资产"] <= val_cfg["max_profit_asset_ratio"]).all()
        
        # 条件2: 连续亏损年数限制
        annual_profit = df.set_index("日期")["净利润"].resample("YE").sum()
        consecutive_loss = (annual_profit < 0).astype(int).groupby((annual_profit >= 0).cumsum()).cumsum()
        loss_condition = (consecutive_loss <= val_cfg["max_consecutive_loss_years"]).all()
        
        # 条件3: 净资产增长倍数限制
        asset_growth_condition = (df["净资产"].iloc[-1] / df["净资产"].iloc[0] <= val_cfg["max_asset_growth_multiple"])
        
        # 条件4: 最小亏损季度数
        loss_quarters_condition = (df["净利润"] < 0).sum() >= val_cfg["min_loss_quarters"]
        
        return all([ratio_condition, loss_condition, asset_growth_condition, loss_quarters_condition])


generator = FinancialDataGenerator()

# 生成数据
financial_data = generator.generate()

# 查看结果
financial_data
# Out:
#            日期    净资产增长率    净利润增长率           净资产           净利润     资产负债表日 公告类型  \
# 0  2020-03-31  0.100153  0.094320  1.980275e+08  2.697755e+06 2020-03-30   季报
# 1  2020-06-30 -0.012658  0.549377  1.955210e+08  1.351925e+07 2020-06-30  半年报
# 2  2020-09-30 -0.058688 -0.553373  1.840462e+08 -3.369272e+06 2020-09-30   季报
# 3  2020-12-31  0.030194  0.978763  1.896032e+08  9.971981e+06 2020-12-30   年报
# 4  2021-03-31  0.049346 -0.103515  1.989594e+08  7.179984e+06 2021-03-30   季报
# 5  2021-06-30 -0.028927 -0.353289  1.932041e+08 -1.362529e+06 2021-06-30  半年报
# 6  2021-09-30  0.007718  0.573698  1.946952e+08  7.608665e+06 2021-09-30   季报
# 7  2021-12-31  0.052645  0.056840  2.049450e+08  9.007430e+06 2021-12-30   年报
# 8  2022-03-31  0.246070 -0.291447  2.553758e+08  1.427640e+06 2022-03-30   季报
# 9  2022-06-30  0.014479  0.587900  2.590732e+08  1.226124e+07 2022-06-30  半年报
# 10 2022-09-30 -0.088237 -0.290037  2.362133e+08  3.774399e+06 2022-09-30   季报
# 11 2022-12-31  0.204289  0.340289  2.844692e+08  1.084369e+07 2022-12-30   年报
# 12 2023-03-31  0.041364 -0.381817  2.962360e+08  2.124862e+05 2023-03-30   季报
# 13 2023-06-30  0.050271  0.555509  3.111282e+08  9.774172e+06 2023-06-30  半年报
# 14 2023-09-30 -0.078206  0.089950  2.867962e+08  1.218251e+07 2023-09-30   季报
# 15 2023-12-31 -0.002212  0.169620  2.861618e+08  1.713246e+07 2023-12-30   年报
# 16 2024-03-31  0.118323  0.223034  3.200213e+08  2.474515e+07 2024-03-30   季报
# 17 2024-06-30  0.102037 -0.721634  3.526753e+08 -5.379572e+06 2024-06-30  半年报
# 18 2024-09-30 -0.056327 -0.016972  3.328102e+08 -5.576788e+06 2024-09-30   季报
# 19 2024-12-31  0.335639  0.287038  4.445145e+08 -2.297894e+06 2024-12-30   年报
#
#          公告日期
# 0  2020-04-30
# 1  2020-08-27
# 2  2020-10-27
# 3  2021-03-30
# 4  2021-04-30
# 5  2021-08-27
# 6  2021-10-27
# 7  2022-03-30
# 8  2022-04-30
# 9  2022-08-27
# 10 2022-10-27
# 11 2023-03-30
# 12 2023-04-30
# 13 2023-08-27
# 14 2023-10-27
# 15 2024-03-30
# 16 2024-04-30
# 17 2024-08-27
# 18 2024-10-27
# 19 2025-03-30

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pandas.tseries.offsets import CustomBusinessDay


# 绘制图表
fig, ax1 = plt.subplots(figsize=(14, 7))

financial_df = financial_data

# 绘制净资产及净利润
ax2 = ax1.twinx()
ax1.plot(financial_df['日期'], financial_df['净资产'], color='blue', label='净资产')
ax1.plot(financial_df['日期'], financial_df['净利润'], color='green', label='净利润')
ax1.set_ylabel('净资产 / 净利润', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
lines_1, labels_1 = ax1.get_legend_handles_labels()  # 获取图例信息

# 绘制净资产增长率和净利润增长率的柱状图
width = 5  # 设置柱状图的宽度
ax2.bar(financial_df['日期'], financial_df['净资产增长率'], width=width, alpha=0.35, color='orange', label='净资产增长率')
ax2.bar(financial_df['日期'], financial_df['净利润增长率'], width=width, alpha=0.35, color='red', label='净利润增长率')
ax2.set_ylabel('增长率', color='orange')
ax2.tick_params(axis='y', labelcolor='orange')
lines_2, labels_2 = ax2.get_legend_handles_labels()  # 获取图例信息

# 合并和显示图例
lines = lines_1 + lines_2
labels = labels_1 + labels_2
ax1.legend(lines, labels, loc='upper left')

# 加横线
ax1.axhline(0, color='gray', linewidth=0.8)
ax2.axhline(0, color='gray', linewidth=0.8)  # 在增长率为0的位置添加横线

# 标题和网格
plt.title('净资产和净利润及其增长率的模拟')
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.show()

# %% [markdown]
# ### 交易数据

# %%
import pandas as pd
import numpy as np
from pandas.tseries.offsets import CustomBusinessDay

DEFAULT_TRADING_CONFIG = {
    # 时间范围配置
    "date_range": {
        "start_date": "2020-01-01",
        "end_date": "2024-12-31"
    },
    
    # 市场参数配置
    "market_params": {
        "initial_price": 15.0,           # 初始股价
        "initial_shares": 1e8,           # 初始总股本(股)
        "mean_return": 0.0002,           # 日均收益率
        "return_std": 0.02,              # 收益率标准差
        "trading_days_per_year": 242,    # 年交易天数估算
        "corp_action_prob": 0.005        # 每天发生公司行为的概率
    },
    
    # 公司行为参数配置
    "corporate_actions": {
        "现金分红": {
            "prob": 0.6,                 # 在发生公司行为时，选择现金分红的概率
            "min_div": 0.1,              # 最小每股分红金额
            "max_div": 0.5               # 最大每股分红金额
        },
        "送股": {
            "prob": 0.25,                # 送股的概率
            "min_ratio": 0.1,            # 最小送股比例(10送1)
            "max_ratio": 0.5             # 最大送股比例(10送5)
        },
        "配股": {
            "prob": 0.15,                # 配股的概率
            "min_ratio": 0.1,            # 最小配股比例(10配1)
            "max_ratio": 0.3,            # 最大配股比例(10配3)
            "min_price_ratio": 0.7,      # 配股价相对于市价的最小比例
            "max_price_ratio": 0.9       # 配股价相对于市价的最大比例
        }
    },
    
    # 假期配置（可根据实际情况调整）
    "holiday_rules": {
        "new_year_days": 1,              # 新年放假天数
        "spring_festival": {
            "start_month": 1, 
            "start_day": 24,
            "duration": 7
        },
        "qingming": {
            "start_month": 4,
            "start_day": 4,
            "duration": 3
        },
        "labor_day": {
            "start_month": 5,
            "start_day": 1,
            "duration": 5
        },
        "dragon_boat": {
            "start_month": 6,
            "start_day": 25,
            "duration": 3
        },
        "national_day": {
            "start_month": 10,
            "start_day": 1,
            "duration": 7
        }
    }
}

class TradingDataGenerator:
    def __init__(self, config=None):
        self.config = config or DEFAULT_TRADING_CONFIG
        self.trading_days = None
        self._prepare_calendar()
        
    def _prepare_calendar(self):
        """准备交易日历"""
        # 生成假期日期
        years = pd.date_range(
            start=self.config["date_range"]["start_date"],
            end=self.config["date_range"]["end_date"]
        ).year.unique()
        
        self.holidays = self._generate_holidays(years)
        
        # 创建交易日历
        trading_cal = CustomBusinessDay(holidays=self.holidays)
        self.trading_days = pd.date_range(
            start=self.config["date_range"]["start_date"],
            end=self.config["date_range"]["end_date"],
            freq=trading_cal
        )
    
    def _generate_holidays(self, years):
        """生成中国假期日期列表"""
        holidays = []
        for year in years:
            # 新年
            holidays.append(f"{year}-01-01")
            
            # 生成各假期
            h_rules = self.config["holiday_rules"]
            holidays += self._create_holiday_range(year, h_rules["spring_festival"])
            holidays += self._create_holiday_range(year, h_rules["qingming"])
            holidays += self._create_holiday_range(year, h_rules["labor_day"])
            holidays += self._create_holiday_range(year, h_rules["dragon_boat"])
            holidays += self._create_holiday_range(year, h_rules["national_day"])
        
        return pd.to_datetime(holidays).date.tolist()
    
    def _create_holiday_range(self, year, rule):
        """创建假期日期范围"""
        start_date = pd.Timestamp(year, rule["start_month"], rule["start_day"])
        return pd.date_range(
            start=start_date,
            periods=rule["duration"]
        ).strftime("%Y-%m-%d").tolist()
    
    def _generate_corporate_actions(self, df):
        """生成公司行为数据并计算复权因子和原始价格"""
        # 初始化公司行为相关列
        df['公司行为'] = None
        # 初始化复权因子和总股本仅在收盘价不为空的情况下
        df.loc[~df['收盘价'].isna(), '复权因子'] = 1.0
        df.loc[~df['收盘价'].isna(), '总股本'] = self.config["market_params"]["initial_shares"]
        
        # 公司行为类型及其概率
        actions = list(self.config["corporate_actions"].keys())
        action_probs = [self.config["corporate_actions"][a]["prob"] for a in actions]
        
        # 每天有一定概率发生公司行为
        for i in range(1, len(df)):
            # 跳过上市前的日期
            if pd.isna(df.loc[i, '收盘价']):
                continue
                
            # 检查是否发生公司行为
            if np.random.random() < self.config["market_params"]["corp_action_prob"]:
                # 选择公司行为类型
                action = np.random.choice(actions, p=action_probs)
                df.loc[i, '公司行为'] = action
                
                # 获取前一天的收盘价、复权因子和总股本
                prev_close = df.loc[i-1, '收盘价']
                prev_adj_factor = df.loc[i-1, '复权因子']
                prev_shares = df.loc[i-1, '总股本']
                
                # 处理不同类型的公司行为
                if action == "现金分红":
                    # 随机生成分红金额
                    div_amount = np.random.uniform(
                        self.config["corporate_actions"][action]["min_div"],
                        self.config["corporate_actions"][action]["max_div"]
                    )
                    # 更新复权因子: 复权因子 *= 除息前价格 / (除息前价格 - 分红)
                    adj_factor_change = prev_close / (prev_close - div_amount)
                    df.loc[i:, '复权因子'] = df.loc[i:, '复权因子'] * adj_factor_change
                    # 现金分红不影响总股本
                    df.loc[i:, '总股本'] = prev_shares
                    
                elif action == "送股":
                    # 随机生成送股比例
                    bonus_ratio = np.random.uniform(
                        self.config["corporate_actions"][action]["min_ratio"],
                        self.config["corporate_actions"][action]["max_ratio"]
                    )
                    # 更新复权因子: 复权因子 *= (1 + 送股比例)
                    df.loc[i:, '复权因子'] = df.loc[i:, '复权因子'] * (1 + bonus_ratio)
                    # 更新总股本: 总股本 *= (1 + 送股比例)
                    df.loc[i:, '总股本'] = prev_shares * (1 + bonus_ratio)
                    
                elif action == "配股":
                    # 随机生成配股比例和配股价
                    rights_ratio = np.random.uniform(
                        self.config["corporate_actions"][action]["min_ratio"],
                        self.config["corporate_actions"][action]["max_ratio"]
                    )
                    rights_price_ratio = np.random.uniform(
                        self.config["corporate_actions"][action]["min_price_ratio"],
                        self.config["corporate_actions"][action]["max_price_ratio"]
                    )
                    rights_price = prev_close * rights_price_ratio
                    
                    # 计算理论除权价
                    ex_rights_price = (prev_close + rights_ratio * rights_price) / (1 + rights_ratio)
                    # 更新复权因子: 复权因子 *= 除权前价格 / 除权后价格
                    adj_factor_change = prev_close / ex_rights_price
                    df.loc[i:, '复权因子'] = df.loc[i:, '复权因子'] * adj_factor_change
                    # 更新总股本: 总股本 *= (1 + 配股比例)
                    df.loc[i:, '总股本'] = prev_shares * (1 + rights_ratio)
        
        # 计算原始收盘价 = 复权收盘价 / 复权因子
        df['原始收盘价'] = df['收盘价'] / df['复权因子']
        
        return df
    
    def generate(self):
        """生成完整的交易数据"""
        params = self.config["market_params"]
        
        # 生成收益率序列
        returns = np.random.normal(
            params["mean_return"],
            params["return_std"],
            len(self.trading_days)
        )
        
        # 计算复权价格序列（具有正态收益率特性）
        adj_prices = params["initial_price"] * (1 + returns).cumprod()
        
        # 构建DataFrame
        df = pd.DataFrame({
            "日期": self.trading_days,
            "日收益率": returns,
            "收盘价": adj_prices  # 这是复权后的收盘价
        })
        
        # 添加前收盘价
        df["前收盘价"] = df["收盘价"].shift(1)

        # 添加上市日期
        # 过滤出在2021-01-01到2022-09-01之间的日期
        filtered_dates = df[(df['日期'] >= '2021-01-03') & (df['日期'] <= '2021-09-01')]['日期']
        # 从过滤后的日期中随机选择一个日期
        listing_date = filtered_dates.sample(n=1).iloc[0]
        df['上市日期'] = listing_date
    
        # 假设发行价格等于发行当日的收盘价
        df['发行价格'] = df.loc[df['日期'] == listing_date, '收盘价'].values[0]   
        
        # 将上市日期之前的数据替换为NaN
        df.loc[df['日期'] < listing_date, ['日收益率', '收盘价', '前收盘价', '发行价格']] = np.nan
        
        # 生成公司行为数据并计算原始价格
        df = self._generate_corporate_actions(df)
        
        # 清理首行空值
        return df
    

trading_gen = TradingDataGenerator()
trading_df = trading_gen.generate()

trading_df
# Out:
#              日期      日收益率        收盘价       前收盘价       上市日期       发行价格  公司行为  \
# 0    2020-01-02       NaN        NaN        NaN 2021-07-15        NaN  None
# 1    2020-01-03       NaN        NaN        NaN 2021-07-15        NaN  None
# 2    2020-01-06       NaN        NaN        NaN 2021-07-15        NaN  None
# 3    2020-01-07       NaN        NaN        NaN 2021-07-15        NaN  None
# 4    2020-01-08       NaN        NaN        NaN 2021-07-15        NaN  None
# ...         ...       ...        ...        ...        ...        ...   ...
# 1209 2024-12-25  0.000234  29.430157  29.423262 2021-07-15  15.548759  None
# 1210 2024-12-26  0.014963  29.870530  29.430157 2021-07-15  15.548759  None
# 1211 2024-12-27 -0.017494  29.347966  29.870530 2021-07-15  15.548759  None
# 1212 2024-12-30 -0.038289  28.224271  29.347966 2021-07-15  15.548759  None
# 1213 2024-12-31  0.028200  29.020189  28.224271 2021-07-15  15.548759  None
#
#           复权因子           总股本      原始收盘价
# 0          NaN           NaN        NaN
# 1          NaN           NaN        NaN
# 2          NaN           NaN        NaN
# 3          NaN           NaN        NaN
# 4          NaN           NaN        NaN
# ...        ...           ...        ...
# 1209  2.979714  2.793837e+08   9.876838
# 1210  2.979714  2.793837e+08  10.024629
# 1211  2.979714  2.793837e+08   9.849255
# 1212  2.979714  2.793837e+08   9.472140
# 1213  2.979714  2.793837e+08   9.739252
#
# [1214 rows x 10 columns]

# %%
# 统计每个项的出现次数
action_counts = trading_df["公司行为"].value_counts()

# 计算每个项的比例
action_ratios = trading_df["公司行为"].value_counts(normalize=True)

# 将结果组合成一个 DataFrame
result = pd.DataFrame({
    "出现次数": action_counts,
    "比例": action_ratios
})

# 输出结果
print(result)
# Out:
#       出现次数   比例
# 公司行为
# 送股       4  0.5
# 现金分红     4  0.5

# %%
trading_df.columns
# Out:
# Index(['日期', '日收益率', '收盘价', '前收盘价', '上市日期', '发行价格', '公司行为', '复权因子', '总股本',
#        '原始收盘价'],
#       dtype='object')

# %% [markdown]
# | 行为类型 | 复权因子调整 | 总股本变化 | 参数范围 |
# |----------|--------------|------------|----------|
# | 现金分红 | 下调（1 - 分红率） | 不变 | 分红率：1%~5% |
# | 送股 | 上调（1 + 送股比例） | 增加（1 + 送股比例） | 送股比例：5%~20% |
# | 配股 | 按公式调整（考虑配股价和比例） | 增加（1 + 配股比例） | 配股比例：10%~30%，配股价为市价70%~90% |

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np

# 假设trading_df是您的DataFrame
# 首先确保日期是datetime类型
trading_df['日期'] = pd.to_datetime(trading_df['日期'])

# 创建画布和主坐标轴
fig, ax1 = plt.subplots(figsize=(15, 8))

# 1. 绘制收盘价和后复权收盘价
ax1.plot(trading_df['日期'], trading_df['原始收盘价'], 
        label='原始收盘价', color='green', linewidth=1.2, alpha=0.7)
ax1.plot(trading_df['日期'], trading_df['收盘价'], 
        label='收盘价', color='blue', linewidth=1.5)
ax1.set_ylabel('价格', fontsize=12)
ax1.grid(True, linestyle='--', alpha=0.7)
ax1.legend(loc='upper left')

# 创建次坐标轴用于总股本
ax2 = ax1.twinx()
ax2.plot(trading_df['日期'], trading_df['总股本'], 
        label='总股本', color='red', linewidth=1.2, linestyle='--')
ax2.set_ylabel('总股本', fontsize=12)
ax2.legend(loc='upper right')

# 创建第三个坐标轴用于复权因子
ax3 = ax1.twinx()

# 调整第三个坐标轴的位置，使其与其他坐标轴不重叠
ax3.spines['right'].set_position(('outward', 60))  # 将坐标轴向右偏移60像素
ax3.plot(trading_df['日期'], trading_df['复权因子'], 
         label='复权因子', color='purple', linewidth=1.2, linestyle='-.')
ax3.set_ylabel('复权因子', fontsize=12)
ax3.legend(loc='lower right')

# 3. 标记公司行为
# 获取有公司行为的日期
action_dates = trading_df[trading_df['公司行为'].notna()]

# 为不同类型的公司行为设置不同颜色
action_colors = {
    '现金分红': 'green',
    '送股': 'blue',
    '配股': 'red'
}

for date, row in action_dates.iterrows():
    color = action_colors.get(row['公司行为'], 'purple')  # 默认为紫色
    
    # 在主图中添加垂直线
    ax1.axvline(x=row['日期'], color=color, linestyle='--', 
               alpha=0.7, linewidth=1)
    
    # 在主图上添加文本标注
    ax1.text(row['日期'], ax1.get_ylim()[1]*0.95, row['公司行为'],
            rotation=90, verticalalignment='top', 
            horizontalalignment='right', color=color,
            bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))

# 设置x轴格式 - 使用与之前相同的方法
# 每月一个刻度
ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# 格式化为年-月
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
# 旋转45度
plt.setp(ax1.get_xticklabels(), rotation=45, ha='right')

# 调整布局
plt.tight_layout()
plt.title('股票走势及公司行为标记 (包含原始收盘价和后复权收盘价对比)', 
         y=1.02, fontsize=14)
plt.show()

# %% [markdown]
# ### 整合数据

# %%
import pandas as pd
import numpy as np

def merge_financial_trade_data(financial_df, tread_df):
    """
    合并财务数据和交易数据
    """
    # 转换日期列为 datetime 类型，并去除时区信息和时间部分
    financial_df['日期'] = pd.to_datetime(financial_df['日期']).dt.date
    financial_df['公告日期'] = pd.to_datetime(financial_df['公告日期']).dt.date
    tread_df['日期'] = pd.to_datetime(tread_df['日期']).dt.date

    # 读取 tread_df 的第一日和最后一日
    start_date = tread_df['日期'].min()
    end_date = tread_df['日期'].max()

    # 创建包含全部日期的序列
    all_dates = pd.date_range(start=start_date, end=end_date, freq='D').date
    combined_company_info = pd.DataFrame({'日期': all_dates})

    # 将 tread_df 的数据按照日期填入
    combined_company_info = combined_company_info.merge(tread_df, on='日期', how='left')

    # 遍历 combined_company_info，根据 '日期' 去匹配 financial_df
    for idx, row in combined_company_info.iterrows():
        current_date = row['日期']

        # 找到 financial_df 中 '公告日期' 早于当前日期的最晚的一行
        matching_rows = financial_df[financial_df['公告日期'] <= current_date]

        if not matching_rows.empty:
            latest_row = matching_rows.loc[matching_rows['公告日期'].idxmax()]

            # 删除 latest_row 中的 '日期' 列
            latest_row = latest_row.drop('日期')

            # 将这一行数据拼接到 combined_company_info
            for col in latest_row.index:
                if col not in combined_company_info.columns:
                    if '公告类型' in col:
                        combined_company_info[col] = ''
                    elif '日期' in col:
                        combined_company_info[col] = '' # pd.NaT
                    else:
                        combined_company_info[col] = np.nan  # 添加新列并初始化为 NaN
                combined_company_info.at[idx, col] = latest_row[col]

    # 将 <NA> 替换为 NaN
    combined_company_info = combined_company_info.replace({pd.NA: np.nan})

    # 筛选出交易日，并删除非交易日的行
    trade_dates = tread_df['日期']
    combined_company_info = combined_company_info[combined_company_info['日期'].isin(trade_dates)]

    # 计算每股净资产、每股净利润及其他列
    combined_company_info['每股净资产'] = combined_company_info['净资产'] / combined_company_info['总股本']
    combined_company_info['每股净利润'] = combined_company_info['净利润'] / combined_company_info['总股本']
    combined_company_info['收盘价减每股净资产'] = combined_company_info['收盘价'] - combined_company_info['每股净资产']
    combined_company_info['收盘价减每股净利润'] = combined_company_info['收盘价'] - combined_company_info['每股净利润']

    return combined_company_info



combined_company_info = merge_financial_trade_data(financial_data, trading_df)
combined_company_info = combined_company_info.dropna(subset=['净资产'])
combined_company_info
# Out:
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
#               日期      日收益率        收盘价       前收盘价       上市日期       发行价格 公司行为  \
# 119   2020-04-30       NaN        NaN        NaN 2021-07-15        NaN  NaN
# 125   2020-05-06       NaN        NaN        NaN 2021-07-15        NaN  NaN
# 126   2020-05-07       NaN        NaN        NaN 2021-07-15        NaN  NaN
# 127   2020-05-08       NaN        NaN        NaN 2021-07-15        NaN  NaN
# 130   2020-05-11       NaN        NaN        NaN 2021-07-15        NaN  NaN
# ...          ...       ...        ...        ...        ...        ...  ...
# 1819  2024-12-25  0.000234  29.430157  29.423262 2021-07-15  15.548759  NaN
# 1820  2024-12-26  0.014963  29.870530  29.430157 2021-07-15  15.548759  NaN
# 1821  2024-12-27 -0.017494  29.347966  29.870530 2021-07-15  15.548759  NaN
# 1824  2024-12-30 -0.038289  28.224271  29.347966 2021-07-15  15.548759  NaN
# 1825  2024-12-31  0.028200  29.020189  28.224271 2021-07-15  15.548759  NaN
#
#           复权因子           总股本      原始收盘价  ...    净利润增长率           净资产  \
# 119        NaN           NaN        NaN  ...  0.094320  1.980275e+08
# 125        NaN           NaN        NaN  ...  0.094320  1.980275e+08
# 126        NaN           NaN        NaN  ...  0.094320  1.980275e+08
# 127        NaN           NaN        NaN  ...  0.094320  1.980275e+08
# 130        NaN           NaN        NaN  ...  0.094320  1.980275e+08
# ...        ...           ...        ...  ...       ...           ...
# 1819  2.979714  2.793837e+08   9.876838  ... -0.016972  3.328102e+08
# 1820  2.979714  2.793837e+08  10.024629  ... -0.016972  3.328102e+08
# 1821  2.979714  2.793837e+08   9.849255  ... -0.016972  3.328102e+08
# 1824  2.979714  2.793837e+08   9.472140  ... -0.016972  3.328102e+08
# 1825  2.979714  2.793837e+08   9.739252  ... -0.016972  3.328102e+08
#
#                净利润     资产负债表日 公告类型        公告日期    每股净资产     每股净利润  收盘价减每股净资产  \
# 119   2.697755e+06 2020-03-30   季报  2020-04-30      NaN       NaN        NaN
# 125   2.697755e+06 2020-03-30   季报  2020-04-30      NaN       NaN        NaN
# 126   2.697755e+06 2020-03-30   季报  2020-04-30      NaN       NaN        NaN
# 127   2.697755e+06 2020-03-30   季报  2020-04-30      NaN       NaN        NaN
# 130   2.697755e+06 2020-03-30   季报  2020-04-30      NaN       NaN        NaN
# ...            ...        ...  ...         ...      ...       ...        ...
# 1819 -5.576788e+06 2024-09-30   季报  2024-10-27  1.19123 -0.019961  28.238927
# 1820 -5.576788e+06 2024-09-30   季报  2024-10-27  1.19123 -0.019961  28.679300
# 1821 -5.576788e+06 2024-09-30   季报  2024-10-27  1.19123 -0.019961  28.156736
# 1824 -5.576788e+06 2024-09-30   季报  2024-10-27  1.19123 -0.019961  27.033041
# 1825 -5.576788e+06 2024-09-30   季报  2024-10-27  1.19123 -0.019961  27.828959
#
#       收盘价减每股净利润
# 119         NaN
# 125         NaN
# 126         NaN
# 127         NaN
# 130         NaN
# ...         ...
# 1819  29.450118
# 1820  29.890491
# 1821  29.367927
# 1824  28.244232
# 1825  29.040150
#
# [1135 rows x 21 columns]

# %% [markdown]
# ### 法律数据

# %%
import numpy as np
import pandas as pd
from collections import defaultdict

def simulate_legal_events(
    df,
    # 事件触发概率参数
    prob_investigation_start=0.003,
    prob_prosecution_start=0.002,
    prob_condemn=0.005,
    prob_penalty_after_investigation=0.5,
    prob_conviction_after_prosecution=0.5,
    # 时间范围参数（天）
    min_days_investigation=10,
    max_days_investigation=30,
    min_days_penalty=5,
    max_days_penalty=60,
    min_days_prosecution=15,
    max_days_prosecution=45,
    min_days_conviction=10,
    max_days_conviction=30,
    seed=None
):
    # 初始化设置
    if seed is not None:
        np.random.seed(seed)
    
    df = df.copy()
    dates = df["日期"].tolist()
    date_index = {d: i for i, d in enumerate(dates)}
    n = len(dates)
    
    # 使用空字符串初始化列
    df["公司涉嫌证券期货违法犯罪事件"] = ""
    occupied = set()

    # 处理证监会流程
    investigation_events = _process_flow(
        dates, occupied,
        start_event="被中国证监会及其派出机构立案调查",
        end_event="中国证监会及其派出机构立案调查结束",
        follow_event="行政处罚决定作出",
        start_prob=prob_investigation_start,
        follow_prob=prob_penalty_after_investigation,
        min_duration=min_days_investigation,
        max_duration=max_days_investigation,
        min_follow=min_days_penalty,
        max_follow=max_days_penalty
    )

    # 处理司法流程
    prosecution_events = _process_flow(
        dates, occupied,
        start_event="被司法机关立案侦查",
        end_event="司法机关立案侦查结束",
        follow_event="刑事判决作出",
        start_prob=prob_prosecution_start,
        follow_prob=prob_conviction_after_prosecution,
        min_duration=min_days_prosecution,
        max_duration=max_days_prosecution,
        min_follow=min_days_conviction,
        max_follow=max_days_conviction
    )

    # 合并所有事件
    all_events = defaultdict(str)
    for events in [investigation_events, prosecution_events]:
        for date, event in events.items():
            all_events[date] = event

    # 处理公开谴责（只在剩余日期中处理）
    for i, date in enumerate(dates):
        if date not in occupied:
            if np.random.rand() < prob_condemn:
                all_events[date] = "被本所公开谴责"
                occupied.add(date)

    # 填充到DataFrame
    for date, event in all_events.items():
        df.loc[df["日期"] == date, "公司涉嫌证券期货违法犯罪事件"] = event

    return df

def _process_flow(
    dates, 
    occupied, 
    start_event, 
    end_event, 
    follow_event, 
    start_prob, 
    follow_prob, 
    min_duration, 
    max_duration, 
    min_follow, 
    max_follow
):
    date_index = {d: i for i, d in enumerate(dates)}
    events = {}
    n = len(dates)

    for i in range(n):
        current_date = dates[i]
        if current_date in occupied:
            continue

        # 尝试触发开始事件
        if np.random.rand() < start_prob:
            # 记录开始事件
            events[current_date] = start_event
            occupied.add(current_date)
            
            # 计算持续时间（核心修改点）
            duration = np.random.randint(min_duration, max_duration+1)
            end_day = i + duration
            
            # 查找结束日期（必须晚于开始日期）
            end_idx = _find_next_available(end_day, dates, occupied, n)
            if end_idx is None:
                continue
                
            # 记录结束事件
            events[dates[end_idx]] = end_event
            occupied.add(dates[end_idx])
            
            # 处理后续事件
            if np.random.rand() < follow_prob:
                follow_duration = np.random.randint(min_follow, max_follow+1)
                follow_day = end_idx + follow_duration
                follow_idx = _find_next_available(follow_day, dates, occupied, n)
                if follow_idx is not None:
                    events[dates[follow_idx]] = follow_event
                    occupied.add(dates[follow_idx])

    return events

def _find_next_available(start_idx, dates, occupied, max_idx):
    """
    从指定位置开始找到第一个可用日期
    返回日期索引或None
    """
    idx = start_idx
    while idx < max_idx:
        if dates[idx] not in occupied:
            return idx
        idx += 1
    return None

# %%
# 运行模拟函数
simulated_df = simulate_legal_events(
    combined_company_info,
    prob_investigation_start=0.0001,
    prob_prosecution_start=0.0001,
    prob_condemn=0.0005,
    # seed=42
)

# 查看结果
slice_df = simulated_df[simulated_df["公司涉嫌证券期货违法犯罪事件"] != ""]
slice_df[['日期', '公司涉嫌证券期货违法犯罪事件']]
# Out:
#              日期 公司涉嫌证券期货违法犯罪事件
# 237  2020-08-26        被本所公开谴责

# %%
simulated_df.columns
# Out:
# Index(['日期', '日收益率', '收盘价', '前收盘价', '上市日期', '发行价格', '公司行为', '复权因子', '总股本',
#        '原始收盘价', '净资产增长率', '净利润增长率', '净资产', '净利润', '资产负债表日', '公告类型', '公告日期',
#        '每股净资产', '每股净利润', '收盘价减每股净资产', '收盘价减每股净利润', '公司涉嫌证券期货违法犯罪事件'],
#       dtype='object')

# %% [markdown]
# ### 退市风险警示

# %%
import numpy as np
import pandas as pd

def simulate_delisting_risk(
    df,
    prob_restriction_start=0.005,
    min_days_restriction=30,
    max_days_restriction=180,
    seed=None
):
    # 初始化设置
    if seed is not None:
        np.random.seed(seed)
    
    df = df.copy()
    dates = df["日期"].tolist()
    date_index = {d: i for i, d in enumerate(dates)}
    n = len(dates)
    
    # 使用空字符串初始化列
    df["退市风险警示"] = ""
    occupied = set()
    events = {}

    # 处理减持限制流程
    for i in range(n):
        current_date = dates[i]
        if current_date in occupied:
            continue

        # 尝试触发限制开始事件
        if np.random.rand() < prob_restriction_start:
            # 计算限制持续时间
            duration = np.random.randint(min_days_restriction, max_days_restriction+1)
            end_day = i + duration
            
            # 查找结束日期（必须晚于开始日期）
            end_idx = _find_next_available(end_day, dates, occupied, n)
            if end_idx is None:
                continue
                
            # 记录开始和结束事件
            events[current_date] = "限制减持期限开始"
            occupied.add(current_date)
            events[dates[end_idx]] = "限制减持期限结束"
            occupied.add(dates[end_idx])

    # 填充到DataFrame
    for date, event in events.items():
        df.loc[df["日期"] == date, "退市风险警示"] = event

    return df

def _find_next_available(start_idx, dates, occupied, max_idx):
    """
    从指定位置开始找到第一个可用日期
    返回日期索引或None
    """
    idx = start_idx
    while idx < max_idx:
        if dates[idx] not in occupied:
            return idx
        idx += 1
    return None

# %%
# 运行模拟函数
simulated_df = simulate_delisting_risk(
    combined_company_info,
    prob_restriction_start=0.001,
    min_days_restriction=30,
    max_days_restriction=90,
)

# 查看结果
slice_df = simulated_df[simulated_df["退市风险警示"] != ""]
slice_df[['日期', '退市风险警示']]
# Out:
#               日期    退市风险警示
# 1138  2023-02-13  限制减持期限开始
# 1243  2023-05-29  限制减持期限结束

# %% [markdown]
# ### 股东减持活动

# %% [markdown]
# 需要生成的变量
#
# 股东的属性: [持股5%以下股东, 持股5%以上股东, 董监高, 离任董监高, 控股股东, 实际控制人, ]
# - 不考虑具体是什么董监高, 不考虑一致行动人等情况
#
# 拟减持股份来源: [北交所上市前取得, ]
# - 不考虑竞价交易取得, 做市交易取得等情况, 因为他们不需要遵守第四条进行披露. 受限制很少. (第七条)
# - 同理不考虑参与向不特定合格投资者公开发行并上市、上市公司向不特定对象或者特定对象公开发行而取得的上市公司股份. (第七条)

# %%
import pandas as pd
import numpy as np
from typing import Dict

# ========================
# 配置参数
# ========================
CONFIG = {
    # 身份转换概率
    'prob_dongjingao_to_common': 0.001,  # 董监高每日转为普通/5%股东概率
    'prob_common_to_dongjingao': 0.005,  # 普通股东转董监高概率
    'prob_control_to_common': 0.005,     # 控股股东转为普通/5%股东概率
    'prob_actual_to_common': 0.005,      # 实际控制人转为普通/5%股东概率
    'prob_to_dongjingao': 0.01,          # 控股股东/实际控制人转为董监高概率

    # 减持计划生成
    'prob_initiate_plan': 0.05,          # 无计划时每日发起计划概率
    'max_plan_ratio': 0.1,               # 计划减持比例上限（按公司所有股份=1计算）
    
    # 减持执行
    'prob_execute_sale': 0.2,            # 符合条件时每日减持概率
}

# ========================
# 工具函数
# ========================
def days_between(start_date: pd.Timestamp, end_date: pd.Timestamp) -> int:
    """
    计算两个日期之间的自然日数量
    """
    return (end_date - start_date).days

# ========================
# 核心处理函数
# ========================
def update_shareholder_identity(prev_row: pd.Series, current_date: pd.Timestamp) -> Dict:
    """
    更新股东身份状态
    返回需要更新的字段字典
    
    简化后的身份转换规则：
    1. 董监高离任直接转为普通股东或持股5%以上股东
    2. 控股股东/实际控制人离任直接转为普通股东或持股5%以上股东
    3. 控股股东/实际控制人持股比例<30%时自动转为持股5%以上股东
    4. 普通股东和持股5%以上股东可以相互转换
    5. 普通股东/持股5%以上股东可以转为董监高
    6. 控股股东/实际控制人有概率转为董监高
    """
    updates = {}
    holding_ratio = prev_row['持股比例']
    
    # 持股比例导致的自动转换（优先级最高）
    if prev_row['股东身份'] in ['控股股东', '实际控制人'] and holding_ratio < 0.3:
        updates['股东身份'] = '持股5%以上股东' if holding_ratio >= 0.05 else '普通股东'
        return updates
    
    # 普通股东和持股5%以上股东之间的转换
    if prev_row['股东身份'] == '普通股东' and holding_ratio >= 0.05:
        updates['股东身份'] = '持股5%以上股东'
    elif prev_row['股东身份'] == '持股5%以上股东' and holding_ratio < 0.05:
        updates['股东身份'] = '普通股东'
    
    # 董监高 -> 普通/持股5%以上股东
    if prev_row['股东身份'] == '董监高' and np.random.rand() < CONFIG['prob_dongjingao_to_common']:
        new_identity = '普通股东' if holding_ratio < 0.05 else '持股5%以上股东'
        updates['股东身份'] = new_identity
    
    # 普通/持股5%以上股东 -> 董监高
    elif prev_row['股东身份'] in ['普通股东', '持股5%以上股东']:
        if np.random.rand() < CONFIG['prob_common_to_dongjingao'] and holding_ratio >= 0.05:
            updates['股东身份'] = '董监高'
    
    # 控股股东 -> 普通/持股5%以上股东或董监高
    elif prev_row['股东身份'] == '控股股东':
        if np.random.rand() < CONFIG['prob_control_to_common']:
            new_identity = '普通股东' if holding_ratio < 0.05 else '持股5%以上股东'
            updates['股东身份'] = new_identity
        elif np.random.rand() < CONFIG['prob_to_dongjingao']:
            updates['股东身份'] = '董监高'
    
    # 实际控制人 -> 普通/持股5%以上股东或董监高
    elif prev_row['股东身份'] == '实际控制人':
        if np.random.rand() < CONFIG['prob_actual_to_common']:
            new_identity = '普通股东' if holding_ratio < 0.05 else '持股5%以上股东'
            updates['股东身份'] = new_identity
        elif np.random.rand() < CONFIG['prob_to_dongjingao']:
            updates['股东身份'] = '董监高'
    
    return updates


def generate_reduction_plan(prev_row: pd.Series, current_date: pd.Timestamp, df) -> Dict:
    """
    生成新的减持计划（如果触发）
    返回计划相关字段字典
    """
    # print(row)

    # 判断是否满足发起计划的条件
    if (prev_row['持股比例'] > 0 
            and np.random.rand() < CONFIG['prob_initiate_plan']):

        # 计算预披露时间要求
        plan_ratio = np.random.uniform(0, min(prev_row['持股比例'], CONFIG['max_plan_ratio']))
        min_days = 30 if plan_ratio > 0.01 else 15

        # 有一定概率不按要求, 直接10天
        random_value = np.random.rand()
        if random_value < 0.3:
            # 0.3的概率不考虑披露时间要求，直接设计成10天
            min_days = 10

        # 计算初步的开始日期和结束日期
        start_date = current_date + pd.Timedelta(days=min_days)
        end_date = start_date + pd.DateOffset(months=3)

        # 检查 start_date 和 end_date 是否在交易日中
        if start_date not in df['日期'].values or end_date not in df['日期'].values:
            # print('尝试发起计划但日期不合适')
            return {}  # 如果计算出的日期不在交易日中，返回空字典
        
        # 根据定义的概率分布生成减持方式
        choices = ['竞价交易', '大宗交易', '协议转让', '融券卖出', ]
        probabilities = [0.3, 0.2, 0.4, 0.10]
        reduction_way = np.random.choice(choices, p=probabilities)

        reduction_reason = '个人资金需求'  # 暂不考虑离婚, 司法强制执行、继承、遗赠、依法分割财产等情况
       
        return {
            '存在减持计划': True,
            '计划披露日': current_date,
            '计划开始日': start_date,  
            '计划结束日': end_date,    
            '计划减持比例': plan_ratio,
            '减持方式': reduction_way,
            '拟减持原因': reduction_reason, 
            '计划价格下限': prev_row['收盘价'] * 0.9,
            '计划价格上限': prev_row['收盘价'] * 1.1,
            '累计减持比例': 0.0
        }
    
    return {}


def execute_reduction_plan(prev_row: pd.Series, current_row: Dict) -> Dict:
    """
    执行减持操作（如果条件满足）
    修改current_row字典
    """
    # print(f"prev_row['存在减持计划']: {prev_row['存在减持计划']}")
    # print(f"prev_row['计划开始日']: {prev_row['计划开始日']}")
    # print(f"current_row['日期']: {current_row['日期']}")
    # print(f"prev_row['计划结束日']: {prev_row['计划结束日']}")

    if (not pd.isna(prev_row['存在减持计划']) and prev_row['存在减持计划'] and
        not pd.isna(prev_row['计划开始日']) and not pd.isna(prev_row['计划结束日']) and
        prev_row['计划开始日'] <= current_row['日期'] <= prev_row['计划结束日']):
        
        # 价格区间检查
        price_ok = (current_row['收盘价'] >= prev_row['计划价格下限']) and \
                   (current_row['收盘价'] <= prev_row['计划价格上限'])
        
        # 减持量检查
        remaining = prev_row['计划减持比例'] - prev_row['累计减持比例']
        
        if price_ok and remaining > 0 and np.random.rand() < CONFIG['prob_execute_sale']:
            # 简化：每次减持计划量的5%（可优化为基于剩余时间）
            sale_ratio = min(remaining, prev_row['计划减持比例'] * 0.05)
            current_row['当日减持比例'] = sale_ratio
            current_row['累计减持比例'] = prev_row['累计减持比例'] + sale_ratio
    
    return current_row


# def execute_increase_holding(prev_row: pd.Series, current_row: Dict) -> Dict:
#     """
#     执行增持操作（如果触发）
#     """
#     if np.random.rand() < CONFIG['prob_increase_holding']:
#         # 计算增持比例（基于前一日持股比例）
#         increase_ratio = np.random.uniform(*CONFIG['increase_ratio_range']) * prev_row['持股比例']
#         current_row['当日增持比例'] = increase_ratio
    
#     return current_row

# ========================
# 主处理流程
# ========================
def main_simulation(df: pd.DataFrame) -> pd.DataFrame:
    
    # 初始化股东状态列
    df['持股比例'] = np.random.uniform(0.03, 0.6)   # 初始值

    # 根据定义的概率分布生成股东身份
    probabilities = [0.2, 0.2, 0.2, 0.4]  
    identities = ['董监高', '控股股东', '实际控制人', '普通股东']
    df['股东身份'] = np.random.choice(identities, p=probabilities)

    # 初始化坚持计划状态
    df['存在减持计划'] = False

    # 检查持股比例和股东身份，进行相应的修改
    df.loc[(df['持股比例'] >= 0.05) & (df['股东身份'] == '普通股东'), '股东身份'] = '持股5%以上股东'
    df.loc[(df['持股比例'] <= 0.3) & (df['股东身份'] == '控股股东'), '股东身份'] = '持股5%以上股东'
    df.loc[(df['持股比例'] <= 0.3) & (df['股东身份'] == '实际控制人'), '股东身份'] = '持股5%以上股东'
    

    # 初始化后续要使用到的columns
    col_list_values = [   
            '计划减持比例',
            '计划价格下限',
            '计划价格上限',
            '当日减持比例',
            '当日增持比例',
            '累计减持比例',
    ]

    col_list_days = [
            '计划披露日',
            '计划开始日',  
            '计划结束日',    
            '离任日期',
    ]

    col_list_str = [
            '减持方式', 
            '拟减持原因', 
    ]

    for col in col_list_values:
        df[col] = np.nan

    for col in col_list_days:
        df[col] = pd.NaT  # 使用 NaT 初始化日期列
    
    for col in col_list_str:
        df[col] = pd.NA  

    for i in range(1, len(df)):
        prev = df.iloc[i-1].copy()
        current_row = df.iloc[i].copy()
        current_date = current_row['日期']

        date_diff = pd.to_datetime(current_row['日期']) - pd.to_datetime(current_row['上市日期'])

        if date_diff.days <= 30:
            continue


        # print(f"现在在处理日期: {current_date}")
        
        current_row['当日减持比例'] = 0.0  # 重置
        current_row['当日增持比例'] = 0.0
        current_row['股东身份'] = prev['股东身份']
        current_row['离任日期'] = prev['离任日期'] # 本质上是最近一次离任日
        current_row['计划披露日'] = prev['计划披露日'] # 本质上是"最近一次的计划的披露日"
        current_row['减持方式'] = prev['减持方式']
        current_row['拟减持原因'] = prev['拟减持原因']
        
        # === 状态更新阶段 ===

        # 0. 从前一行判断减持计划是否存在
        # 如果前一行的'存在减持计划'为True, 并且前一行的'计划结束日'非空且大于当前日期，
        # 那么就把前一行的 ['计划披露日','计划开始日', '计划结束日', '计划减持比例',
        # '计划价格下限','计划价格上限','累计减持比例'] 都抄到 current_row
        if prev['存在减持计划'] == True and not pd.isna(prev['计划结束日']) and prev['计划结束日'] > current_date:
            current_row['存在减持计划'] = True
            columns_to_copy = [
                '计划披露日', '计划开始日', '计划结束日', 
                '计划减持比例', '减持方式','拟减持原因', 
                '计划价格下限', '计划价格上限', '累计减持比例'
            ]
            for col in columns_to_copy:
                current_row[col] = prev[col]

        
        # 1. 更新股东身份
        identity_updates = update_shareholder_identity(prev, current_date)
        current_row.update(identity_updates)
        # 打印更新股东身份的结果
        if len(identity_updates) > 0:
            print(f"更新股东身份的结果: {identity_updates}")
        
        # 2. 生成减持计划
        if current_row['存在减持计划'] == False:
            plan_updates = generate_reduction_plan(prev, current_date, df)
            current_row.update(plan_updates)
            if len(plan_updates) > 0:
                print(f"生成减持计划的结果: {plan_updates}")
        
        # === 减持执行阶段 ===
        if current_row['存在减持计划'] == True:
            current_row = execute_reduction_plan(prev, current_row)
            # # 打印减持执行的结果:
            # if current_row['当日减持比例'] != 0:
            #     print(f"减持执行的结果: 当日减持比例={current_row['当日减持比例']}, 累计减持比例={current_row.get('累计减持比例', 'N/A')}")
        
        # # === 增持情况 ===
        # current_row = execute_increase_holding(prev, current_row)
        
        # === 后处理 ===
        current_row['持股比例'] = prev['持股比例'] - current_row['当日减持比例'] 

        # 更新持股比例（需先于其他依赖持股比例的操作）
        # current_row['持股比例'] = prev['持股比例'] - current_row['当日减持比例'] + current_row['当日增持比例']
        
        # === 更新到总的df ===
        df.iloc[i] = current_row
    
    df['持股数量'] = df['持股比例'] * df['总股本']
    df['当日减持数量'] = df['当日减持比例'] * df['总股本']
    df['股份来源'] = '北交所上市前取得'

    new_column_order = [
    # 交易和股东持仓
    '日期', '收盘价', '前收盘价', '日收益率', '复权因子', 
    '持股比例', '股东身份', '持股数量', '股份来源',
    
    # 股东增持减持行为
    '累计减持比例', '当日减持比例', # '当日增持比例', 
    
    # 减持计划相关
    '存在减持计划', '计划减持比例', '计划价格下限', '计划价格上限',
    '计划披露日', '计划开始日', '计划结束日', '离任日期', 
    '减持方式', '拟减持原因',
    
    # 财务相关
    '上市日期', '发行价格', '净资产', '每股净资产', 
    '收盘价减每股净资产', '净利润', '每股净利润', 
    '收盘价减每股净利润', '净资产增长率', '净利润增长率',
    '总股本', '公告类型', '公告日期'
    ]

    # 调整列顺序
    df = df[new_column_order]
    
    return df

# %%
generator = FinancialDataGenerator()
financial_data = generator.generate()

trading_gen = TradingDataGenerator()
trading_df = trading_gen.generate()

combined_company_info = merge_financial_trade_data(financial_data, trading_df)

combined_company_info_copy = combined_company_info.copy()
combined_company_info_copy['日期'] = pd.to_datetime(combined_company_info_copy['日期'])
# 运行模拟
one_company_one_holder_df = main_simulation(combined_company_info_copy)

draw_financial_and_treading(combined_company_info)
plot_timeline(one_company_one_holder_df)
# Out:
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-06-07 00:00:00'), '计划开始日': Timestamp('2021-06-17 00:00:00'), '计划结束日': Timestamp('2021-09-17 00:00:00'), '计划减持比例': 0.05234899957781247, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(11.797752710719346), '计划价格上限': np.float64(14.419475535323645), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-11-16 00:00:00'), '计划开始日': Timestamp('2021-12-16 00:00:00'), '计划结束日': Timestamp('2022-03-16 00:00:00'), '计划减持比例': 0.052013049738414335, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(9.88747745332599), '计划价格上限': np.float64(12.084694665176212), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-08-09 00:00:00'), '计划开始日': Timestamp('2022-09-08 00:00:00'), '计划结束日': Timestamp('2022-12-08 00:00:00'), '计划减持比例': 0.024721113386015736, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(18.9375131179671), '计划价格上限': np.float64(23.145849366404235), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-02-24 00:00:00'), '计划开始日': Timestamp('2023-03-06 00:00:00'), '计划结束日': Timestamp('2023-06-06 00:00:00'), '计划减持比例': 0.003407366181853245, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(21.318889776527033), '计划价格上限': np.float64(26.056420837977484), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-08-16 00:00:00'), '计划开始日': Timestamp('2023-09-15 00:00:00'), '计划结束日': Timestamp('2023-12-15 00:00:00'), '计划减持比例': 0.010915395865629219, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(19.232402790733637), '计划价格上限': np.float64(23.506270077563336), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-04-08 00:00:00'), '计划开始日': Timestamp('2024-04-18 00:00:00'), '计划结束日': Timestamp('2024-07-18 00:00:00'), '计划减持比例': 0.009742547954038411, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(20.038405589768054), '计划价格上限': np.float64(24.491384609716512), '累计减持比例': 0.0}

# %%
one_company_one_holder_df.columns
# Out:
# Index(['日期', '收盘价', '前收盘价', '日收益率', '复权因子', '持股比例', '股东身份', '持股数量', '股份来源',
#        '累计减持比例', '当日减持比例', '存在减持计划', '计划减持比例', '计划价格下限', '计划价格上限', '计划披露日',
#        '计划开始日', '计划结束日', '离任日期', '减持方式', '拟减持原因', '上市日期', '发行价格', '净资产',
#        '每股净资产', '收盘价减每股净资产', '净利润', '每股净利润', '收盘价减每股净利润', '净资产增长率', '净利润增长率',
#        '总股本', '公告类型', '公告日期'],
#       dtype='object')

# %% [markdown]
# ## 批量生成

# %%
import pandas as pd
import random

# 定义一些偏门的汉字
prefixes = ["曦", "昱", "沅", "淼", "珏", "琬", "瑾", "鸾", "翰", "裴", "霖", "钧", "铄", "骁", "颢", "麒", "筠", "珣", "芷", "蔚", "璟", "翊", "旻", "暄", "泓", "澜", "玥", "祎", "昀"]
suffixes = ["珺", "滢", "瀚", "骞", "琛", "煜", "瑄", "璨", "祺", "颉", "瀚", "霆", "翊", "琨", "璐", "璞", "琰", "璟", "琮", "琯", "瑾", "珹", "璋", "珵", "琮", "瑗", "璜", "琛", "璱", "玮"]
industries = ["股份", "科技", "实业", "集团", "控股", "电力", "化工", "物流", "医药", "地产", "机械", "农业", "传媒", "食品", "环保", "信息", "能源", "交通", "建筑", "生物"]

# 生成公司名字列表，确保不重复
company_names = []
used_company_combinations = set()  # 用于跟踪已使用的公司组合

while len(company_names) < 50:
    prefix = random.choice(prefixes)
    suffix = random.choice(suffixes)
    industry = random.choice(industries)
    combination = (prefix, suffix, industry)  # 使用元组来跟踪组合
    
    if combination not in used_company_combinations:
        used_company_combinations.add(combination)
        company_name = f"{prefix}{suffix}{industry}"
        company_names.append(company_name)

# 定义一些常见的姓氏
surnames = ["王", "李", "张", "刘", "陈", "杨", "黄", "赵", "周", "吴", "徐", "孙", "马", "朱", "胡", "郭", "何", "高", "林", "罗", "梁", "宋", "郑", "谢", "韩", "唐", "冯", "于", "董", "萧"]

# 生成自然人名字列表，确保不重复
person_names = []
used_person_combinations = set()  # 用于跟踪已使用的人名组合

while len(person_names) < 30:
    surname = random.choice(surnames)
    given_name_prefix = random.choice(prefixes)
    given_name_suffix = random.choice(suffixes)
    combination = (surname, given_name_prefix, given_name_suffix)
    
    if combination not in used_person_combinations:
        used_person_combinations.add(combination)
        person_name = f"{surname}{given_name_prefix}{given_name_suffix}"
        person_names.append(person_name)

# 生成公司名字列表（股东），确保不重复且不与公司主体重复
shareholder_company_names = []
used_shareholder_combinations = set()  # 用于跟踪已使用的股东公司组合
company_suffixes = ["资本", "投资", "基金", "控股", "实业"]

while len(shareholder_company_names) < 20:
    prefix = random.choice(prefixes)
    suffix = random.choice(suffixes)
    company_suffix = random.choice(company_suffixes)
    combination = (prefix, suffix, company_suffix)
    
    # 检查是否已使用，同时确保不与公司主体名称重复
    if (combination not in used_shareholder_combinations and 
        (prefix, suffix) not in {(c[0], c[1]) for c in used_company_combinations}):
        used_shareholder_combinations.add(combination)
        shareholder_company_name = f"{prefix}{suffix}{company_suffix}"
        shareholder_company_names.append(shareholder_company_name)

# 合并自然人名字和公司名字作为股东名字
shareholder_names = person_names + shareholder_company_names

# 确保股东分配不重复（每个股东最多出现一次）
random.shuffle(shareholder_names)
if len(shareholder_names) < 50:
    # 如果股东数量不足，循环使用但确保不连续重复
    repeated_shareholders = (shareholder_names * ((50 // len(shareholder_names)) + 1))[:50]
    # 检查并调整相邻重复
    for i in range(1, len(repeated_shareholders)):
        if repeated_shareholders[i] == repeated_shareholders[i-1]:
            # 找到下一个不同的股东交换
            for j in range(i+1, len(repeated_shareholders)):
                if repeated_shareholders[j] != repeated_shareholders[i-1]:
                    repeated_shareholders[i], repeated_shareholders[j] = repeated_shareholders[j], repeated_shareholders[i]
                    break
    shareholder_assignment = repeated_shareholders
else:
    shareholder_assignment = shareholder_names[:50]

# 创建DataFrame
data = {
    "公司": company_names,
    "股东": shareholder_assignment
}

company_holder_df = pd.DataFrame(data)

# 检查是否有重复的公司名称或股东分配问题
assert len(company_names) == len(set(company_names)), "存在重复的公司名称"
assert len(shareholder_names) == len(set(shareholder_names)), "存在重复的股东名称"

company_holder_df
# Out:
#       公司    股东
# 0   钧璋机械   马翊璟
# 1   泓琨实业   冯旻瑗
# 2   暄琛农业   唐蔚滢
# 3   昱瑗食品  骁骞资本
# 4   钧璟交通   王泓霆
# 5   暄琨医药  旻璞实业
# 6   璟璨交通   胡祎琯
# 7   暄瑾食品   萧璟琨
# 8   昀璨食品  昱瀚基金
# 9   筠璟农业   宋珏翊
# 10  祎瑾股份  珏瑾实业
# 11  祎璟电力  瑾滢投资
# 12  玥琨实业  璟璜投资
# 13  祎煜集团  澜颉实业
# 14  翰璞食品   冯珏琮
# 15  铄琛物流  鸾璨资本
# 16  泓骞物流   陈钧瀚
# 17  泓琛控股  祎琮投资
# 18  翰煜传媒   林曦琛
# 19  翰璐交通  澜玮资本
# 20  曦璞交通  骁琰投资
# 21  暄瑗医药   韩翊颉
# 22  铄珹农业  瑾瑗资本
# 23  璟珹建筑   吴颢琛
# 24  芷璐控股   胡澜琮
# 25  昱琛电力  泓珵控股
# 26  祎璱化工   胡铄璞
# 27  泓琰地产   吴琬珹
# 28  蔚玮集团   萧珏瑗
# 29  翊琮建筑   张澜琨
# 30  骁珹交通  筠琰基金
# 31  翊瀚集团   梁翰珹
# 32  暄璨建筑  琬璜投资
# 33  珏珺医药   吴蔚珵
# 34  淼珹科技   董芷瑗
# 35  暄琯控股   周麒煜
# 36  翰璐建筑   何铄瑗
# 37  麒瑾科技   陈翰颉
# 38  钧煜交通  旻璞控股
# 39  珏琮实业   孙玥琛
# 40  沅玮科技   陈霖翊
# 41  泓霆电力   何珏珺
# 42  玥璋交通   林颢祺
# 43  珏祺食品  蔚煜投资
# 44  裴琮物流   韩祎珹
# 45  祎璨信息  翊颉实业
# 46  霖璋机械  蔚琯实业
# 47  昀琛交通   王泓祺
# 48  钧珺信息   萧玥琨
# 49  沅璐股份  玥滢控股

# %%
from tqdm import tqdm
import pandas as pd

# 启用tqdm的pandas集成
tqdm.pandas(desc="Processing Companies")

all_company_results_list = []

# 使用pandas集成的progress_apply来显示进度条
for id, row in tqdm(company_holder_df.iterrows(), total=company_holder_df.shape[0], desc="Processing each company"):
    # 生成财务数据
    generator = FinancialDataGenerator()
    financial_data = generator.generate()
    
    # 生成交易数据 
    trading_gen = TradingDataGenerator()
    trading_df = trading_gen.generate()

    # 去掉财务数据为空的部分
    combined_company_info = merge_financial_trade_data(financial_data, trading_df)
    combined_company_info = combined_company_info.dropna(subset=['净资产'])

    # 生成公司层面的法律事件
    combined_company_info = simulate_legal_events(
        combined_company_info,
        prob_investigation_start=0.001,
        prob_prosecution_start=0.001,
        prob_condemn=0.005,
        # seed=42
    )

    # 生成退市风险警示
    combined_company_info = simulate_delisting_risk(
        combined_company_info,
        prob_restriction_start=0.01, 
        min_days_restriction=30, 
        max_days_restriction=90,
    )

    combined_company_info['日期'] = pd.to_datetime(combined_company_info['日期'])
    
    # 运行模拟
    result_df = main_simulation(combined_company_info)

    combined_company_info['公司简称'] = row['公司']
    combined_company_info['股东'] = row['股东']

    # 生成股东层面的法律事件
    combined_company_info_temp = simulate_legal_events(
        combined_company_info,
        prob_investigation_start=0.001,
        prob_prosecution_start=0.001,
        prob_condemn=0.005,
        # seed=42
    )
    # simulate_legal_events默认返回的是"公司涉嫌证券期货违法犯罪事件"的column, 需要修改
    combined_company_info["股东涉嫌证券期货违法犯罪事件"] = combined_company_info_temp["公司涉嫌证券期货违法犯罪事件"]

    # 将'存在减持计划'为False的行的指定列设置为空值
    combined_company_info.loc[combined_company_info['存在减持计划'] == False, ['计划披露日', '减持方式', '拟减持原因']] = [pd.NaT, pd.NA, pd.NA]

    # 将['当日减持比例']的None设置为0
    combined_company_info['当日减持比例'] = combined_company_info['当日减持比例'].fillna(0)


    # 将DataFrame添加到列表中
    all_company_results_list.append(combined_company_info)

# 使用pd.concat一次性合并所有的DataFrame
all_company_results = pd.concat(all_company_results_list, ignore_index=True)
all_company_results
# Out:
# Processing each company:   0%|          | 0/50 [00:00<?, ?it/s]/var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-11-08 00:00:00'), '计划开始日': Timestamp('2021-11-23 00:00:00'), '计划结束日': Timestamp('2022-02-23 00:00:00'), '计划减持比例': 0.0013144297080486035, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(17.039232940031322), '计划价格上限': np.float64(20.825729148927174), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-03-28 00:00:00'), '计划开始日': Timestamp('2022-04-27 00:00:00'), '计划结束日': Timestamp('2022-07-27 00:00:00'), '计划减持比例': 0.04007067034768737, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(21.78232600529735), '计划价格上限': np.float64(26.62284289536343), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-11-07 00:00:00'), '计划开始日': Timestamp('2022-12-07 00:00:00'), '计划结束日': Timestamp('2023-03-07 00:00:00'), '计划减持比例': 0.049620081733572366, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(33.87088451892144), '计划价格上限': np.float64(41.39774774534843), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-06-19 00:00:00'), '计划开始日': Timestamp('2023-07-19 00:00:00'), '计划结束日': Timestamp('2023-10-19 00:00:00'), '计划减持比例': 0.02608451562760058, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(27.484839923516695), '计划价格上限': np.float64(33.59258212874263), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '持股5%以上股东'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-02-13 00:00:00'), '计划开始日': Timestamp('2024-02-23 00:00:00'), '计划结束日': Timestamp('2024-05-23 00:00:00'), '计划减持比例': 0.05286421609325273, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(29.891963072943668), '计划价格上限': np.float64(36.53462153359782), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-08-07 00:00:00'), '计划开始日': Timestamp('2024-09-06 00:00:00'), '计划结束日': Timestamp('2024-12-06 00:00:00'), '计划减持比例': 0.09118480992890224, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(27.795425663394127), '计划价格上限': np.float64(33.97218692192616), '累计减持比例': 0.0}
# Processing each company:   2%|▏         | 1/50 [00:01<01:19,  1.63s/it]/var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-09-17 00:00:00'), '计划开始日': Timestamp('2021-09-27 00:00:00'), '计划结束日': Timestamp('2021-12-27 00:00:00'), '计划减持比例': 0.07406255762899737, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(24.58111137697728), '计划价格上限': np.float64(30.04358057186112), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '持股5%以上股东'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-01-19 00:00:00'), '计划开始日': Timestamp('2022-02-18 00:00:00'), '计划结束日': Timestamp('2022-05-18 00:00:00'), '计划减持比例': 0.047172238560149196, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(21.294244368744156), '计划价格上限': np.float64(26.026298672909526), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-06-01 00:00:00'), '计划开始日': Timestamp('2022-06-16 00:00:00'), '计划结束日': Timestamp('2022-09-16 00:00:00'), '计划减持比例': 0.007198241478411783, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(25.076943555851813), '计划价格上限': np.float64(30.64959767937444), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-12-20 00:00:00'), '计划开始日': Timestamp('2023-01-19 00:00:00'), '计划结束日': Timestamp('2023-04-19 00:00:00'), '计划减持比例': 0.03631465835356347, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(27.444487625044037), '计划价格上限': np.float64(33.5432626528316), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-04-24 00:00:00'), '计划开始日': Timestamp('2023-05-24 00:00:00'), '计划结束日': Timestamp('2023-08-24 00:00:00'), '计划减持比例': 0.0997579569973498, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(28.82055280909827), '计划价格上限': np.float64(35.225120100009), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-09-06 00:00:00'), '计划开始日': Timestamp('2023-09-21 00:00:00'), '计划结束日': Timestamp('2023-12-21 00:00:00'), '计划减持比例': 0.0007120948385161863, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(32.080862466666105), '计划价格上限': np.float64(39.20994301481413), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-04-08 00:00:00'), '计划开始日': Timestamp('2024-04-18 00:00:00'), '计划结束日': Timestamp('2024-07-18 00:00:00'), '计划减持比例': 0.09037147342331912, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(23.79880956320935), '计划价格上限': np.float64(29.087433910589205), '累计减持比例': 0.0}
# Processing each company:   4%|▍         | 2/50 [00:03<01:16,  1.59s/it]/var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-11-30 00:00:00'), '计划开始日': Timestamp('2021-12-10 00:00:00'), '计划结束日': Timestamp('2022-03-10 00:00:00'), '计划减持比例': 0.07280227937312152, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(19.203007975318826), '计划价格上限': np.float64(23.470343080945234), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-05-23 00:00:00'), '计划开始日': Timestamp('2022-06-22 00:00:00'), '计划结束日': Timestamp('2022-09-22 00:00:00'), '计划减持比例': 0.045527190967489334, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(24.602143473108477), '计划价格上限': np.float64(30.069286467132585), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '持股5%以上股东'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-10-10 00:00:00'), '计划开始日': Timestamp('2022-11-09 00:00:00'), '计划结束日': Timestamp('2023-02-09 00:00:00'), '计划减持比例': 0.07886384383461885, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(20.134310156222423), '计划价格上限': np.float64(24.608601302049628), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-03-14 00:00:00'), '计划开始日': Timestamp('2023-04-13 00:00:00'), '计划结束日': Timestamp('2023-07-13 00:00:00'), '计划减持比例': 0.06464351860210325, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(12.508615783570157), '计划价格上限': np.float64(15.288308179919083), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-09-12 00:00:00'), '计划开始日': Timestamp('2023-10-12 00:00:00'), '计划结束日': Timestamp('2024-01-12 00:00:00'), '计划减持比例': 0.06307181096446098, '减持方式': np.str_('融券卖出'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(9.669890271361725), '计划价格上限': np.float64(11.818754776108776), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-02-27 00:00:00'), '计划开始日': Timestamp('2024-03-28 00:00:00'), '计划结束日': Timestamp('2024-06-28 00:00:00'), '计划减持比例': 0.05215532492314967, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(12.389279056230134), '计划价格上限': np.float64(15.142452179836832), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-07-01 00:00:00'), '计划开始日': Timestamp('2024-07-31 00:00:00'), '计划结束日': Timestamp('2024-10-31 00:00:00'), '计划减持比例': 0.011653935450904719, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(15.237934045267092), '计划价格上限': np.float64(18.624141610882003), '累计减持比例': 0.0}
# Processing each company:   6%|▌         | 3/50 [00:04<01:12,  1.55s/it]/var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-07-12 00:00:00'), '计划开始日': Timestamp('2021-08-11 00:00:00'), '计划结束日': Timestamp('2021-11-11 00:00:00'), '计划减持比例': 0.07935260596552654, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(33.447548469690595), '计划价格上限': np.float64(40.88033701851073), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-11-30 00:00:00'), '计划开始日': Timestamp('2021-12-10 00:00:00'), '计划结束日': Timestamp('2022-03-10 00:00:00'), '计划减持比例': 0.08045329423700268, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(39.80120779877124), '计划价格上限': np.float64(48.64592064294263), '累计减持比例': 0.0}
# Processing each company:   8%|▊         | 4/50 [00:06<01:13,  1.61s/it]
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-07-05 00:00:00'), '计划开始日': Timestamp('2022-08-04 00:00:00'), '计划结束日': Timestamp('2022-11-04 00:00:00'), '计划减持比例': 0.07981052794891483, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(35.38054364513256), '计划价格上限': np.float64(43.24288667738424), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-02-13 00:00:00'), '计划开始日': Timestamp('2023-02-23 00:00:00'), '计划结束日': Timestamp('2023-05-23 00:00:00'), '计划减持比例': 0.02606220017477748, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(38.14892108052292), '计划价格上限': np.float64(46.6264590984169), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-06-18 00:00:00'), '计划开始日': Timestamp('2024-07-18 00:00:00'), '计划结束日': Timestamp('2024-10-18 00:00:00'), '计划减持比例': 0.05627033061801556, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(24.628470350122317), '计划价格上限': np.float64(30.10146376126061), '累计减持比例': 0.0}
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-07-13 00:00:00'), '计划开始日': Timestamp('2021-08-12 00:00:00'), '计划结束日': Timestamp('2021-11-12 00:00:00'), '计划减持比例': 0.05967899070090413, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(10.056296617022028), '计划价格上限': np.float64(12.29102919858248), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-11-15 00:00:00'), '计划开始日': Timestamp('2021-11-25 00:00:00'), '计划结束日': Timestamp('2022-02-25 00:00:00'), '计划减持比例': 0.05372873574095453, '减持方式': np.str_('融券卖出'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(8.66321898520653), '计划价格上限': np.float64(10.588378759696871), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-03-28 00:00:00'), '计划开始日': Timestamp('2022-04-07 00:00:00'), '计划结束日': Timestamp('2022-07-07 00:00:00'), '计划减持比例': 0.06439947628148421, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(9.10526346700447), '计划价格上限': np.float64(11.12865534856102), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-07-19 00:00:00'), '计划开始日': Timestamp('2022-08-18 00:00:00'), '计划结束日': Timestamp('2022-11-18 00:00:00'), '计划减持比例': 0.09990918624376861, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(8.33135297627661), '计划价格上限': np.float64(10.182764748782525), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-11-24 00:00:00'), '计划开始日': Timestamp('2022-12-09 00:00:00'), '计划结束日': Timestamp('2023-03-09 00:00:00'), '计划减持比例': 0.006870927162354667, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(13.188695114545782), '计划价格上限': np.float64(16.119516251111513), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '持股5%以上股东'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-05-30 00:00:00'), '计划开始日': Timestamp('2023-06-29 00:00:00'), '计划结束日': Timestamp('2023-09-29 00:00:00'), '计划减持比例': 0.044519313761140634, '减持方式': np.str_('融券卖出'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(18.07059759193814), '计划价格上限': np.float64(22.08628594570217), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-10-10 00:00:00'), '计划开始日': Timestamp('2023-11-09 00:00:00'), '计划结束日': Timestamp('2024-02-09 00:00:00'), '计划减持比例': 0.05134992416358049, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(15.840151184878358), '计划价格上限': np.float64(19.360184781517994), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-03-26 00:00:00'), '计划开始日': Timestamp('2024-04-10 00:00:00'), '计划结束日': Timestamp('2024-07-10 00:00:00'), '计划减持比例': 0.006444291136687748, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(17.107092002120844), '计划价格上限': np.float64(20.908668002592144), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-07-15 00:00:00'), '计划开始日': Timestamp('2024-07-25 00:00:00'), '计划结束日': Timestamp('2024-10-25 00:00:00'), '计划减持比例': 0.009567284384423997, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(16.95543350576797), '计划价格上限': np.float64(20.723307618160856), '累计减持比例': 0.0}
# Processing each company:  10%|█         | 5/50 [00:07<01:11,  1.59s/it]/var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-03-24 00:00:00'), '计划开始日': Timestamp('2021-04-23 00:00:00'), '计划结束日': Timestamp('2021-07-23 00:00:00'), '计划减持比例': 0.08249005766688562, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(13.852930728957931), '计划价格上限': np.float64(16.93135977983747), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-12-06 00:00:00'), '计划开始日': Timestamp('2021-12-16 00:00:00'), '计划结束日': Timestamp('2022-03-16 00:00:00'), '计划减持比例': 0.05089573194066424, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(11.283331375323794), '计划价格上限': np.float64(13.790738347617971), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '普通股东'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-05-10 00:00:00'), '计划开始日': Timestamp('2022-06-09 00:00:00'), '计划结束日': Timestamp('2022-09-09 00:00:00'), '计划减持比例': 0.02212265396907705, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(12.00188587641922), '计划价格上限': np.float64(14.668971626734603), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-10-10 00:00:00'), '计划开始日': Timestamp('2022-11-09 00:00:00'), '计划结束日': Timestamp('2023-02-09 00:00:00'), '计划减持比例': 0.028229368504891935, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(10.291372465591033), '计划价格上限': np.float64(12.578344124611263), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-02-13 00:00:00'), '计划开始日': Timestamp('2023-02-23 00:00:00'), '计划结束日': Timestamp('2023-05-23 00:00:00'), '计划减持比例': 0.009799780194145213, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(10.917242962803778), '计划价格上限': np.float64(13.343296954537951), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-07-12 00:00:00'), '计划开始日': Timestamp('2023-07-27 00:00:00'), '计划结束日': Timestamp('2023-10-27 00:00:00'), '计划减持比例': 0.005319272619864796, '减持方式': np.str_('融券卖出'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(14.081329196261056), '计划价格上限': np.float64(17.210513462096845), '累计减持比例': 0.0}
# Processing each company:  12%|█▏        | 6/50 [00:09<01:11,  1.63s/it]
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-05-08 00:00:00'), '计划开始日': Timestamp('2024-05-23 00:00:00'), '计划结束日': Timestamp('2024-08-23 00:00:00'), '计划减持比例': 0.00042901188388399294, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(15.498428188069973), '计划价格上限': np.float64(18.94252334097441), '累计减持比例': 0.0}
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-08-09 00:00:00'), '计划开始日': Timestamp('2021-08-19 00:00:00'), '计划结束日': Timestamp('2021-11-19 00:00:00'), '计划减持比例': 0.08957499622863717, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(9.368980154280804), '计划价格上限': np.float64(11.450975744120983), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-09-06 00:00:00'), '计划开始日': Timestamp('2022-09-16 00:00:00'), '计划结束日': Timestamp('2022-12-16 00:00:00'), '计划减持比例': 0.008357866514688795, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(8.738103873302125), '计划价格上限': np.float64(10.679904734035931), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-01-16 00:00:00'), '计划开始日': Timestamp('2023-02-15 00:00:00'), '计划结束日': Timestamp('2023-05-15 00:00:00'), '计划减持比例': 0.08743036837367224, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(7.196340185202628), '计划价格上限': np.float64(8.795526893025434), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-07-26 00:00:00'), '计划开始日': Timestamp('2023-08-10 00:00:00'), '计划结束日': Timestamp('2023-11-10 00:00:00'), '计划减持比例': 0.0031717660217525537, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(8.529427857832479), '计划价格上限': np.float64(10.424856270684142), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-04-23 00:00:00'), '计划开始日': Timestamp('2024-05-23 00:00:00'), '计划结束日': Timestamp('2024-08-23 00:00:00'), '计划减持比例': 0.07896726365288903, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(9.824237777959311), '计划价格上限': np.float64(12.007401728616935), '累计减持比例': 0.0}
# Processing each company:  14%|█▍        | 7/50 [00:11<01:11,  1.65s/it]
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-09-16 00:00:00'), '计划开始日': Timestamp('2024-09-26 00:00:00'), '计划结束日': Timestamp('2024-12-26 00:00:00'), '计划减持比例': 0.0533618595199311, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(9.37804025761064), '计划价格上限': np.float64(11.46204920374634), '累计减持比例': 0.0}
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-07-20 00:00:00'), '计划开始日': Timestamp('2021-08-19 00:00:00'), '计划结束日': Timestamp('2021-11-19 00:00:00'), '计划减持比例': 0.06280586919281346, '减持方式': np.str_('融券卖出'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(19.209328423466413), '计划价格上限': np.float64(23.47806807312562), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-11-24 00:00:00'), '计划开始日': Timestamp('2021-12-24 00:00:00'), '计划结束日': Timestamp('2022-03-24 00:00:00'), '计划减持比例': 0.04495688070657153, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(23.233584351651935), '计划价格上限': np.float64(28.396603096463476), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-03-28 00:00:00'), '计划开始日': Timestamp('2022-04-07 00:00:00'), '计划结束日': Timestamp('2022-07-07 00:00:00'), '计划减持比例': 0.06417719378683263, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(19.21147142863075), '计划价格上限': np.float64(23.48068730165981), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-12-12 00:00:00'), '计划开始日': Timestamp('2023-01-11 00:00:00'), '计划结束日': Timestamp('2023-04-11 00:00:00'), '计划减持比例': 0.016819659688904264, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(13.292630747486157), '计划价格上限': np.float64(16.24654869137197), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-05-15 00:00:00'), '计划开始日': Timestamp('2023-05-25 00:00:00'), '计划结束日': Timestamp('2023-08-25 00:00:00'), '计划减持比例': 0.019730067543751964, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(9.763062696639551), '计划价格上限': np.float64(11.932632184781674), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-09-11 00:00:00'), '计划开始日': Timestamp('2023-10-11 00:00:00'), '计划结束日': Timestamp('2024-01-11 00:00:00'), '计划减持比例': 0.08392118771406676, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(9.77333327709074), '计划价格上限': np.float64(11.94518511644424), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-03-13 00:00:00'), '计划开始日': Timestamp('2024-04-12 00:00:00'), '计划结束日': Timestamp('2024-07-12 00:00:00'), '计划减持比例': 0.0544970119984766, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(13.696324901269605), '计划价格上限': np.float64(16.739952657107295), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-07-29 00:00:00'), '计划开始日': Timestamp('2024-08-08 00:00:00'), '计划结束日': Timestamp('2024-11-08 00:00:00'), '计划减持比例': 0.01778267592362347, '减持方式': np.str_('融券卖出'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(16.373673174817274), '计划价格上限': np.float64(20.01226721366556), '累计减持比例': 0.0}
# Processing each company:  16%|█▌        | 8/50 [00:12<01:08,  1.64s/it]/var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-05-24 00:00:00'), '计划开始日': Timestamp('2021-06-03 00:00:00'), '计划结束日': Timestamp('2021-09-03 00:00:00'), '计划减持比例': 0.09968379809171424, '减持方式': np.str_('融券卖出'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(11.852191275812237), '计划价格上限': np.float64(14.486011559326068), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-09-17 00:00:00'), '计划开始日': Timestamp('2021-09-27 00:00:00'), '计划结束日': Timestamp('2021-12-27 00:00:00'), '计划减持比例': 0.007954499244667169, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(11.461620977481411), '计划价格上限': np.float64(14.008647861366171), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-12-28 00:00:00'), '计划开始日': Timestamp('2022-01-07 00:00:00'), '计划结束日': Timestamp('2022-04-07 00:00:00'), '计划减持比例': 0.06422142708998169, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(11.144940089963576), '计划价格上限': np.float64(13.621593443288816), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-08-12 00:00:00'), '计划开始日': Timestamp('2022-08-22 00:00:00'), '计划结束日': Timestamp('2022-11-22 00:00:00'), '计划减持比例': 0.004916208613814988, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(16.753889582601722), '计划价格上限': np.float64(20.476976156513217), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-11-15 00:00:00'), '计划开始日': Timestamp('2023-11-30 00:00:00'), '计划结束日': Timestamp('2024-02-29 00:00:00'), '计划减持比例': 0.002329365906763059, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(13.28403992355613), '计划价格上限': np.float64(16.236048795457492), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-04-01 00:00:00'), '计划开始日': Timestamp('2024-04-11 00:00:00'), '计划结束日': Timestamp('2024-07-11 00:00:00'), '计划减持比例': 0.014095197875548927, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(11.066094051459451), '计划价格上限': np.float64(13.525226062894886), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-09-13 00:00:00'), '计划开始日': Timestamp('2024-09-23 00:00:00'), '计划结束日': Timestamp('2024-12-23 00:00:00'), '计划减持比例': 0.012401251415859828, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(12.321300193697931), '计划价格上限': np.float64(15.059366903408584), '累计减持比例': 0.0}
# Processing each company:  18%|█▊        | 9/50 [00:14<01:07,  1.64s/it]
# 更新股东身份的结果: {'股东身份': '持股5%以上股东'}
# 更新股东身份的结果: {'股东身份': '董监高'}
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-06-01 00:00:00'), '计划开始日': Timestamp('2021-06-16 00:00:00'), '计划结束日': Timestamp('2021-09-16 00:00:00'), '计划减持比例': 0.004563501027417405, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(15.62022947464501), '计划价格上限': np.float64(19.09139158012168), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '持股5%以上股东'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-10-19 00:00:00'), '计划开始日': Timestamp('2021-11-18 00:00:00'), '计划结束日': Timestamp('2022-02-18 00:00:00'), '计划减持比例': 0.024897981689997517, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(11.186792632090363), '计划价格上限': np.float64(13.672746550332667), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-04-11 00:00:00'), '计划开始日': Timestamp('2022-04-21 00:00:00'), '计划结束日': Timestamp('2022-07-21 00:00:00'), '计划减持比例': 0.02219514078357473, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(9.5935296969013), '计划价格上限': np.float64(11.725425185101589), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-11-11 00:00:00'), '计划开始日': Timestamp('2022-11-21 00:00:00'), '计划结束日': Timestamp('2023-02-21 00:00:00'), '计划减持比例': 0.08027853897965995, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(6.141929280155169), '计划价格上限': np.float64(7.506802453522985), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-06-19 00:00:00'), '计划开始日': Timestamp('2023-07-19 00:00:00'), '计划结束日': Timestamp('2023-10-19 00:00:00'), '计划减持比例': 0.07332956153155022, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(5.355939725157311), '计划价格上限': np.float64(6.546148552970048), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-10-30 00:00:00'), '计划开始日': Timestamp('2023-11-09 00:00:00'), '计划结束日': Timestamp('2024-02-09 00:00:00'), '计划减持比例': 0.02274215108473279, '减持方式': np.str_('融券卖出'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(4.995953732626229), '计划价格上限': np.float64(6.106165673209835), '累计减持比例': 0.0}
# Processing each company:  20%|██        | 10/50 [00:16<01:05,  1.64s/it]
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-03-20 00:00:00'), '计划开始日': Timestamp('2024-04-19 00:00:00'), '计划结束日': Timestamp('2024-07-19 00:00:00'), '计划减持比例': 0.02294707299148372, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(4.738109393375889), '计划价格上限': np.float64(5.7910225919038645), '累计减持比例': 0.0}
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-08-31 00:00:00'), '计划开始日': Timestamp('2021-09-30 00:00:00'), '计划结束日': Timestamp('2021-12-30 00:00:00'), '计划减持比例': 0.06807062435437704, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(14.440685903867415), '计划价格上限': np.float64(17.649727215837952), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-01-17 00:00:00'), '计划开始日': Timestamp('2022-02-16 00:00:00'), '计划结束日': Timestamp('2022-05-16 00:00:00'), '计划减持比例': 0.058840565065938856, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(11.026610335801522), '计划价格上限': np.float64(13.47696818820186), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '持股5%以上股东'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-05-16 00:00:00'), '计划开始日': Timestamp('2022-06-15 00:00:00'), '计划结束日': Timestamp('2022-09-15 00:00:00'), '计划减持比例': 0.09751678205626045, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(11.964435121886297), '计划价格上限': np.float64(14.623198482305474), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-10-10 00:00:00'), '计划开始日': Timestamp('2022-10-20 00:00:00'), '计划结束日': Timestamp('2023-01-20 00:00:00'), '计划减持比例': 0.012321964453693735, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(11.12319576655529), '计划价格上限': np.float64(13.595017048012021), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-03-10 00:00:00'), '计划开始日': Timestamp('2023-03-20 00:00:00'), '计划结束日': Timestamp('2023-06-20 00:00:00'), '计划减持比例': 0.06042770133924709, '减持方式': np.str_('融券卖出'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(10.514752193547537), '计划价格上限': np.float64(12.851363792113657), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-08-07 00:00:00'), '计划开始日': Timestamp('2023-09-06 00:00:00'), '计划结束日': Timestamp('2023-12-06 00:00:00'), '计划减持比例': 0.09754125403816478, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(9.174454674051011), '计划价格上限': np.float64(11.213222379395681), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-12-29 00:00:00'), '计划开始日': Timestamp('2024-01-08 00:00:00'), '计划结束日': Timestamp('2024-04-08 00:00:00'), '计划减持比例': 0.008961799394239705, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(8.786465263240288), '计划价格上限': np.float64(10.739013099515908), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-04-08 00:00:00'), '计划开始日': Timestamp('2024-05-08 00:00:00'), '计划结束日': Timestamp('2024-08-08 00:00:00'), '计划减持比例': 0.03018753658027104, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(11.12660354654041), '计划价格上限': np.float64(13.599182112438282), '累计减持比例': 0.0}
# Processing each company:  22%|██▏       | 11/50 [00:17<01:03,  1.63s/it]
# 更新股东身份的结果: {'股东身份': '普通股东'}
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-08-23 00:00:00'), '计划开始日': Timestamp('2021-09-22 00:00:00'), '计划结束日': Timestamp('2021-12-22 00:00:00'), '计划减持比例': 0.05966237518578528, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(7.754790819611782), '计划价格上限': np.float64(9.4780776684144), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-01-18 00:00:00'), '计划开始日': Timestamp('2022-02-17 00:00:00'), '计划结束日': Timestamp('2022-05-17 00:00:00'), '计划减持比例': 0.05840246959284012, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(9.105743928409161), '计划价格上限': np.float64(11.129242579166753), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-11-02 00:00:00'), '计划开始日': Timestamp('2022-12-02 00:00:00'), '计划结束日': Timestamp('2023-03-02 00:00:00'), '计划减持比例': 0.09434285172973161, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(8.383157324793984), '计划价格上限': np.float64(10.246081174748204), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-03-28 00:00:00'), '计划开始日': Timestamp('2023-04-27 00:00:00'), '计划结束日': Timestamp('2023-07-27 00:00:00'), '计划减持比例': 0.07388603706781986, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(8.664341462735141), '计划价格上限': np.float64(10.589750676676283), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-08-09 00:00:00'), '计划开始日': Timestamp('2023-09-08 00:00:00'), '计划结束日': Timestamp('2023-12-08 00:00:00'), '计划减持比例': 0.06350603370535418, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(8.387481683866444), '计划价格上限': np.float64(10.251366502503432), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-12-13 00:00:00'), '计划开始日': Timestamp('2023-12-28 00:00:00'), '计划结束日': Timestamp('2024-03-28 00:00:00'), '计划减持比例': 0.0077804388917911225, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(7.879290380045351), '计划价格上限': np.float64(9.630243797833208), '累计减持比例': 0.0}
# Processing each company:  24%|██▍       | 12/50 [00:19<01:01,  1.61s/it]
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-04-02 00:00:00'), '计划开始日': Timestamp('2024-04-12 00:00:00'), '计划结束日': Timestamp('2024-07-12 00:00:00'), '计划减持比例': 0.035671663677526826, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(7.053903671251579), '计划价格上限': np.float64(8.621437820418597), '累计减持比例': 0.0}
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-07-12 00:00:00'), '计划开始日': Timestamp('2021-08-11 00:00:00'), '计划结束日': Timestamp('2021-11-11 00:00:00'), '计划减持比例': 0.01263840749031846, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(10.250837491785395), '计划价格上限': np.float64(12.528801378848817), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-05-23 00:00:00'), '计划开始日': Timestamp('2022-06-22 00:00:00'), '计划结束日': Timestamp('2022-09-22 00:00:00'), '计划减持比例': 0.08953046565547085, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(18.425701440530595), '计划价格上限': np.float64(22.520301760648508), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-01-17 00:00:00'), '计划开始日': Timestamp('2023-02-16 00:00:00'), '计划结束日': Timestamp('2023-05-16 00:00:00'), '计划减持比例': 0.09499223448071603, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(34.61567242799691), '计划价格上限': np.float64(42.308044078662896), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-05-22 00:00:00'), '计划开始日': Timestamp('2023-06-01 00:00:00'), '计划结束日': Timestamp('2023-09-01 00:00:00'), '计划减持比例': 0.08254789085992376, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(25.902565553240546), '计划价格上限': np.float64(31.658691231738445), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-09-12 00:00:00'), '计划开始日': Timestamp('2023-10-12 00:00:00'), '计划结束日': Timestamp('2024-01-12 00:00:00'), '计划减持比例': 0.08621595005503083, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(30.770088927587125), '计划价格上限': np.float64(37.60788646705093), '累计减持比例': 0.0}
# Processing each company:  26%|██▌       | 13/50 [00:21<00:59,  1.61s/it]
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-03-20 00:00:00'), '计划开始日': Timestamp('2024-04-19 00:00:00'), '计划结束日': Timestamp('2024-07-19 00:00:00'), '计划减持比例': 0.06099502206004821, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(26.807880706776775), '计划价格上限': np.float64(32.765187530504946), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-08-16 00:00:00'), '计划开始日': Timestamp('2024-08-26 00:00:00'), '计划结束日': Timestamp('2024-11-26 00:00:00'), '计划减持比例': 0.047759079885360725, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(19.483746706177797), '计划价格上限': np.float64(23.813468196439533), '累计减持比例': 0.0}
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-10-25 00:00:00'), '计划开始日': Timestamp('2021-11-04 00:00:00'), '计划结束日': Timestamp('2022-02-04 00:00:00'), '计划减持比例': 0.08409126962762813, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(14.604356266796733), '计划价格上限': np.float64(17.84976877052934), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-05-31 00:00:00'), '计划开始日': Timestamp('2022-06-15 00:00:00'), '计划结束日': Timestamp('2022-09-15 00:00:00'), '计划减持比例': 0.008881722377382073, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(15.993533235643557), '计划价格上限': np.float64(19.54765173245324), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-11-17 00:00:00'), '计划开始日': Timestamp('2022-12-02 00:00:00'), '计划结束日': Timestamp('2023-03-02 00:00:00'), '计划减持比例': 0.008331689395575227, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(14.354427998400206), '计划价格上限': np.float64(17.544300886933588), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-03-29 00:00:00'), '计划开始日': Timestamp('2023-04-28 00:00:00'), '计划结束日': Timestamp('2023-07-28 00:00:00'), '计划减持比例': 0.09057191423327826, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(12.620883270535556), '计划价格上限': np.float64(15.425523997321235), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-11-28 00:00:00'), '计划开始日': Timestamp('2023-12-08 00:00:00'), '计划结束日': Timestamp('2024-03-08 00:00:00'), '计划减持比例': 0.059218472781155565, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(15.151664126891209), '计划价格上限': np.float64(18.5187005995337), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-05-24 00:00:00'), '计划开始日': Timestamp('2024-06-03 00:00:00'), '计划结束日': Timestamp('2024-09-03 00:00:00'), '计划减持比例': 0.009834251077736523, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(10.1666290515934), '计划价格上限': np.float64(12.42587995194749), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-09-10 00:00:00'), '计划开始日': Timestamp('2024-09-20 00:00:00'), '计划结束日': Timestamp('2024-12-20 00:00:00'), '计划减持比例': 0.08738865261978557, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(11.397827415002867), '计划价格上限': np.float64(13.930677951670173), '累计减持比例': 0.0}
# Processing each company:  28%|██▊       | 14/50 [00:22<00:57,  1.59s/it]/var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-09-10 00:00:00'), '计划开始日': Timestamp('2021-09-20 00:00:00'), '计划结束日': Timestamp('2021-12-20 00:00:00'), '计划减持比例': 0.06171363303805097, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(15.057629127206695), '计划价格上限': np.float64(18.40376893325263), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-05-09 00:00:00'), '计划开始日': Timestamp('2022-05-19 00:00:00'), '计划结束日': Timestamp('2022-08-19 00:00:00'), '计划减持比例': 0.008533398575800677, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(13.760861688103507), '计划价格上限': np.float64(16.818830952126508), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-02-07 00:00:00'), '计划开始日': Timestamp('2023-02-17 00:00:00'), '计划结束日': Timestamp('2023-05-17 00:00:00'), '计划减持比例': 0.07310488339942332, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(12.788791706581812), '计划价格上限': np.float64(15.630745419155549), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-06-13 00:00:00'), '计划开始日': Timestamp('2023-07-13 00:00:00'), '计划结束日': Timestamp('2023-10-13 00:00:00'), '计划减持比例': 0.09756402507302153, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(12.706795481200954), '计划价格上限': np.float64(15.530527810356723), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-10-30 00:00:00'), '计划开始日': Timestamp('2023-11-29 00:00:00'), '计划结束日': Timestamp('2024-02-29 00:00:00'), '计划减持比例': 0.08438060465224231, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(14.464126812250404), '计划价格上限': np.float64(17.678377214972716), '累计减持比例': 0.0}
# Processing each company:  30%|███       | 15/50 [00:24<00:55,  1.59s/it]
# ...
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-06-03 00:00:00'), '计划开始日': Timestamp('2024-06-18 00:00:00'), '计划结束日': Timestamp('2024-09-18 00:00:00'), '计划减持比例': 0.003765098444045256, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(16.656662371533827), '计划价格上限': np.float64(20.358142898541345), '累计减持比例': 0.0}
# Processing each company:  92%|█████████▏| 46/50 [01:13<00:06,  1.63s/it]/var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-07-26 00:00:00'), '计划开始日': Timestamp('2021-08-25 00:00:00'), '计划结束日': Timestamp('2021-11-25 00:00:00'), '计划减持比例': 0.015952282162028965, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(14.78655260855185), '计划价格上限': np.float64(18.07245318823004), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-01-04 00:00:00'), '计划开始日': Timestamp('2022-01-14 00:00:00'), '计划结束日': Timestamp('2022-04-14 00:00:00'), '计划减持比例': 0.08313768983484221, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(16.260186032963254), '计划价格上限': np.float64(19.87356070695509), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-04-25 00:00:00'), '计划开始日': Timestamp('2022-05-25 00:00:00'), '计划结束日': Timestamp('2022-08-25 00:00:00'), '计划减持比例': 0.0377959661012866, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(16.596048159208333), '计划价格上限': np.float64(20.28405886125463), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-10-18 00:00:00'), '计划开始日': Timestamp('2022-11-17 00:00:00'), '计划结束日': Timestamp('2023-02-17 00:00:00'), '计划减持比例': 0.03288596703729445, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(16.21472183523418), '计划价格上限': np.float64(19.81799335417511), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '普通股东'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-10-27 00:00:00'), '计划开始日': Timestamp('2023-11-06 00:00:00'), '计划结束日': Timestamp('2024-02-06 00:00:00'), '计划减持比例': 0.0005636943250318443, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(23.49169818689649), '计划价格上限': np.float64(28.712075561762376), '累计减持比例': 0.0}
# Processing each company:  94%|█████████▍| 47/50 [01:15<00:04,  1.62s/it]
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-04-23 00:00:00'), '计划开始日': Timestamp('2024-05-23 00:00:00'), '计划结束日': Timestamp('2024-08-23 00:00:00'), '计划减持比例': 0.031143383309238923, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(24.055256422490196), '计划价格上限': np.float64(29.400868960821352), '累计减持比例': 0.0}
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-05-10 00:00:00'), '计划开始日': Timestamp('2021-06-09 00:00:00'), '计划结束日': Timestamp('2021-09-09 00:00:00'), '计划减持比例': 0.06702125597237127, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(15.565239222277297), '计划价格上限': np.float64(19.02418127167225), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-10-11 00:00:00'), '计划开始日': Timestamp('2021-11-10 00:00:00'), '计划结束日': Timestamp('2022-02-10 00:00:00'), '计划减持比例': 0.047886479695743916, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(17.61257550507071), '计划价格上限': np.float64(21.5264811728642), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-05-10 00:00:00'), '计划开始日': Timestamp('2022-06-09 00:00:00'), '计划结束日': Timestamp('2022-09-09 00:00:00'), '计划减持比例': 0.04730656888342, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(12.910612584919525), '计划价格上限': np.float64(15.77963760379053), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-09-20 00:00:00'), '计划开始日': Timestamp('2022-09-30 00:00:00'), '计划结束日': Timestamp('2022-12-30 00:00:00'), '计划减持比例': 0.08770829440820738, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(12.457791914867249), '计划价格上限': np.float64(15.226190118171083), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-04-03 00:00:00'), '计划开始日': Timestamp('2023-04-13 00:00:00'), '计划结束日': Timestamp('2023-07-13 00:00:00'), '计划减持比例': 0.007677677202167311, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(11.354877083106679), '计划价格上限': np.float64(13.878183101574832), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-07-14 00:00:00'), '计划开始日': Timestamp('2023-07-24 00:00:00'), '计划结束日': Timestamp('2023-10-24 00:00:00'), '计划减持比例': 0.012488568567329772, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(12.937542554147035), '计划价格上限': np.float64(15.812552010624156), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-11-16 00:00:00'), '计划开始日': Timestamp('2023-12-01 00:00:00'), '计划结束日': Timestamp('2024-03-01 00:00:00'), '计划减持比例': 0.00916746230902431, '减持方式': np.str_('融券卖出'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(14.710287833857853), '计划价格上限': np.float64(17.979240685826266), '累计减持比例': 0.0}
# Processing each company:  96%|█████████▌| 48/50 [01:17<00:03,  1.63s/it]/var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-04-20 00:00:00'), '计划开始日': Timestamp('2021-05-20 00:00:00'), '计划结束日': Timestamp('2021-08-20 00:00:00'), '计划减持比例': 0.04731196671341268, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(8.545137399601652), '计划价格上限': np.float64(10.444056821735353), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-08-23 00:00:00'), '计划开始日': Timestamp('2021-09-22 00:00:00'), '计划结束日': Timestamp('2021-12-22 00:00:00'), '计划减持比例': 0.011495912726792047, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(9.084587289070097), '计划价格上限': np.float64(11.103384464419008), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-01-31 00:00:00'), '计划开始日': Timestamp('2022-03-02 00:00:00'), '计划结束日': Timestamp('2022-06-02 00:00:00'), '计划减持比例': 0.014057379775893176, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(10.721596610156254), '计划价格上限': np.float64(13.104173634635423), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-07-15 00:00:00'), '计划开始日': Timestamp('2022-07-25 00:00:00'), '计划结束日': Timestamp('2022-10-25 00:00:00'), '计划减持比例': 0.010690741304338414, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(10.600266527305823), '计划价格上限': np.float64(12.955881311151563), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-11-08 00:00:00'), '计划开始日': Timestamp('2022-12-08 00:00:00'), '计划结束日': Timestamp('2023-03-08 00:00:00'), '计划减持比例': 0.07261495757696815, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(7.84128694178186), '计划价格上限': np.float64(9.583795151066719), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-09-18 00:00:00'), '计划开始日': Timestamp('2023-09-28 00:00:00'), '计划结束日': Timestamp('2023-12-28 00:00:00'), '计划减持比例': 0.018978404819385987, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(8.502634208512788), '计划价格上限': np.float64(10.392108477071186), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-04-23 00:00:00'), '计划开始日': Timestamp('2024-05-08 00:00:00'), '计划结束日': Timestamp('2024-08-08 00:00:00'), '计划减持比例': 0.009935342099412194, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(8.213815394762621), '计划价格上限': np.float64(10.03910770470987), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-08-19 00:00:00'), '计划开始日': Timestamp('2024-09-18 00:00:00'), '计划结束日': Timestamp('2024-12-18 00:00:00'), '计划减持比例': 0.04984097908791513, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(8.236859702408648), '计划价格上限': np.float64(10.067272969610569), '累计减持比例': 0.0}
# Processing each company:  98%|█████████▊| 49/50 [01:18<00:01,  1.65s/it]/var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2020-03-30 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_company_info.at[idx, col] = latest_row[col]
# /var/folders/0l/pjlf4pl90rx7ldkq7jx18ny00000gn/T/ipykernel_27061/3594512326.py:49: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_company_info = combined_company_info.replace({pd.NA: np.nan})
# 更新股东身份的结果: {'股东身份': '持股5%以上股东'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2021-09-13 00:00:00'), '计划开始日': Timestamp('2021-10-13 00:00:00'), '计划结束日': Timestamp('2022-01-13 00:00:00'), '计划减持比例': 0.0533957141468329, '减持方式': np.str_('融券卖出'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(42.91063833097848), '计划价格上限': np.float64(52.44633573786259), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-02-01 00:00:00'), '计划开始日': Timestamp('2022-03-03 00:00:00'), '计划结束日': Timestamp('2022-06-03 00:00:00'), '计划减持比例': 0.049434035477055854, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(41.48679631089929), '计划价格上限': np.float64(50.70608437998802), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2022-09-05 00:00:00'), '计划开始日': Timestamp('2022-09-15 00:00:00'), '计划结束日': Timestamp('2022-12-15 00:00:00'), '计划减持比例': 0.07890750374720339, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(38.3517412546533), '计划价格上限': np.float64(46.874350422354034), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-02-06 00:00:00'), '计划开始日': Timestamp('2023-03-08 00:00:00'), '计划结束日': Timestamp('2023-06-08 00:00:00'), '计划减持比例': 0.0834632229732196, '减持方式': np.str_('大宗交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(35.09333358782713), '计划价格上限': np.float64(42.89185216289983), '累计减持比例': 0.0}
# 更新股东身份的结果: {'股东身份': '董监高'}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2023-07-24 00:00:00'), '计划开始日': Timestamp('2023-08-23 00:00:00'), '计划结束日': Timestamp('2023-11-23 00:00:00'), '计划减持比例': 0.07118944979236136, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(32.80028896785607), '计划价格上限': np.float64(40.08924207182409), '累计减持比例': 0.0}
# Processing each company: 100%|██████████| 50/50 [01:20<00:00,  1.61s/it]
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-01-02 00:00:00'), '计划开始日': Timestamp('2024-01-12 00:00:00'), '计划结束日': Timestamp('2024-04-12 00:00:00'), '计划减持比例': 0.022136555930626165, '减持方式': np.str_('协议转让'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(27.77706263815656), '计划价格上限': np.float64(33.94974322441358), '累计减持比例': 0.0}
# 生成减持计划的结果: {'存在减持计划': True, '计划披露日': Timestamp('2024-08-05 00:00:00'), '计划开始日': Timestamp('2024-08-15 00:00:00'), '计划结束日': Timestamp('2024-11-15 00:00:00'), '计划减持比例': 0.026532771862847065, '减持方式': np.str_('竞价交易'), '拟减持原因': '个人资金需求', '计划价格下限': np.float64(27.266458345637023), '计划价格上限': np.float64(33.32567131133414), '累计减持比例': 0.0}
#               日期      日收益率        收盘价       前收盘价       上市日期       发行价格 公司行为  \
# 0     2020-04-30       NaN        NaN        NaN 2021-05-18        NaN  NaN
# 1     2020-05-06       NaN        NaN        NaN 2021-05-18        NaN  NaN
# 2     2020-05-07       NaN        NaN        NaN 2021-05-18        NaN  NaN
# 3     2020-05-08       NaN        NaN        NaN 2021-05-18        NaN  NaN
# 4     2020-05-11       NaN        NaN        NaN 2021-05-18        NaN  NaN
# ...          ...       ...        ...        ...        ...        ...  ...
# 56745 2024-12-25  0.006500  41.514442  41.246344 2021-06-23  34.538724  NaN
# 56746 2024-12-26  0.021031  42.387518  41.514442 2021-06-23  34.538724  NaN
# 56747 2024-12-27  0.011522  42.875886  42.387518 2021-06-23  34.538724  NaN
# 56748 2024-12-30 -0.006458  42.599006  42.875886 2021-06-23  34.538724  NaN
# 56749 2024-12-31 -0.003309  42.458051  42.599006 2021-06-23  34.538724  NaN
#
#            复权因子           总股本      原始收盘价  ...  计划结束日  离任日期  减持方式  拟减持原因  \
# 0           NaN           NaN        NaN  ...    NaT   NaT  <NA>   <NA>
# 1           NaN           NaN        NaN  ...    NaT   NaT  <NA>   <NA>
# 2           NaN           NaN        NaN  ...    NaT   NaT  <NA>   <NA>
# 3           NaN           NaN        NaN  ...    NaT   NaT  <NA>   <NA>
# 4           NaN           NaN        NaN  ...    NaT   NaT  <NA>   <NA>
# ...         ...           ...        ...  ...    ...   ...   ...    ...
# 56745  1.166629  1.142639e+08  35.584964  ...    NaT   NaT  <NA>   <NA>
# 56746  1.166629  1.142639e+08  36.333339  ...    NaT   NaT  <NA>   <NA>
# 56747  1.166629  1.142639e+08  36.751954  ...    NaT   NaT  <NA>   <NA>
# 56748  1.166629  1.142639e+08  36.514621  ...    NaT   NaT  <NA>   <NA>
# 56749  1.166629  1.142639e+08  36.393798  ...    NaT   NaT  <NA>   <NA>
#
#                持股数量 当日减持数量      股份来源  公司简称    股东  股东涉嫌证券期货违法犯罪事件
# 0               NaN    NaN  北交所上市前取得  钧璋机械   马翊璟
# 1               NaN    NaN  北交所上市前取得  钧璋机械   马翊璟
# 2               NaN    NaN  北交所上市前取得  钧璋机械   马翊璟
# 3               NaN    NaN  北交所上市前取得  钧璋机械   马翊璟
# 4               NaN    NaN  北交所上市前取得  钧璋机械   马翊璟
# ...             ...    ...       ...   ...   ...             ...
# 56745  8.184114e+06    0.0  北交所上市前取得  沅璐股份  玥滢控股
# 56746  8.184114e+06    0.0  北交所上市前取得  沅璐股份  玥滢控股
# 56747  8.184114e+06    0.0  北交所上市前取得  沅璐股份  玥滢控股
# 56748  8.184114e+06    0.0  北交所上市前取得  沅璐股份  玥滢控股
# 56749  8.184114e+06    0.0  北交所上市前取得  沅璐股份  玥滢控股
#
# [56750 rows x 44 columns]

# %%
all_company_results.to_csv('data_generated/data_simulate_08.csv', encoding='utf-8-sig', index=False)

# %% [markdown]
# ### 查看结果

# %%
all_company_results.columns
# Out:
# Index(['日期', '日收益率', '收盘价', '前收盘价', '上市日期', '发行价格', '公司行为', '复权因子', '总股本',
#        '原始收盘价', '净资产增长率', '净利润增长率', '净资产', '净利润', '资产负债表日', '公告类型', '公告日期',
#        '每股净资产', '每股净利润', '收盘价减每股净资产', '收盘价减每股净利润', '公司涉嫌证券期货违法犯罪事件', '退市风险警示',
#        '持股比例', '股东身份', '存在减持计划', '计划减持比例', '计划价格下限', '计划价格上限', '当日减持比例',
#        '当日增持比例', '累计减持比例', '计划披露日', '计划开始日', '计划结束日', '离任日期', '减持方式', '拟减持原因',
#        '持股数量', '当日减持数量', '股份来源', '公司简称', '股东', '股东涉嫌证券期货违法犯罪事件'],
#       dtype='object')

# %%
# 统计"股东身份"的出现次数
value_counts = all_company_results['股东身份'].value_counts()

# 计算占比
value_percentages = all_company_results['股东身份'].value_counts(normalize=True) * 100

# 合并结果为一个 DataFrame，方便查看
result = pd.DataFrame({
    '出现次数': value_counts,
    '占比 (%)': value_percentages
})

# 打印结果
result
# Out:
#            出现次数     占比 (%)
# 股东身份
# 董监高       29239  51.522467
# 持股5%以上股东  20013  35.265198
# 普通股东       5062   8.919824
# 控股股东       1400   2.466960
# 实际控制人      1036   1.825551

# %%
all_company_results[['日期', '公告类型', '公告日期']]
# Out:
#               日期 公告类型        公告日期
# 0     2020-04-30   季报  2020-04-30
# 1     2020-05-06   季报  2020-04-30
# 2     2020-05-07   季报  2020-04-30
# 3     2020-05-08   季报  2020-04-30
# 4     2020-05-11   季报  2020-04-30
# ...          ...  ...         ...
# 56745 2024-12-25   季报  2024-10-27
# 56746 2024-12-26   季报  2024-10-27
# 56747 2024-12-27   季报  2024-10-27
# 56748 2024-12-30   季报  2024-10-27
# 56749 2024-12-31   季报  2024-10-27
#
# [56750 rows x 3 columns]

# %%
slice_df = all_company_results[(all_company_results["公司涉嫌证券期货违法犯罪事件"] != "") | (all_company_results["股东涉嫌证券期货违法犯罪事件"] != "")]
slice_df = slice_df[['公司简称', '股东', '日期', '公司涉嫌证券期货违法犯罪事件', '股东涉嫌证券期货违法犯罪事件']]
slice_df
# Out:
#        公司简称    股东         日期 公司涉嫌证券期货违法犯罪事件 股东涉嫌证券期货违法犯罪事件
# 35     钧璋机械   马翊璟 2020-06-23        被本所公开谴责
# 230    钧璋机械   马翊璟 2021-04-13      被司法机关立案侦查
# 264    钧璋机械   马翊璟 2021-06-03     司法机关立案侦查结束
# 352    钧璋机械   马翊璟 2021-10-13      被司法机关立案侦查
# 388    钧璋机械   马翊璟 2021-12-02     司法机关立案侦查结束
# ...     ...   ...        ...            ...            ...
# 56477  沅璐股份  玥滢控股 2023-11-20        被本所公开谴责
# 56536  沅璐股份  玥滢控股 2024-02-19                       被本所公开谴责
# 56707  沅璐股份  玥滢控股 2024-11-01        被本所公开谴责
# 56708  沅璐股份  玥滢控股 2024-11-04        被本所公开谴责
# 56715  沅璐股份  玥滢控股 2024-11-13        被本所公开谴责
#
# [1091 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 假设 all_company_results 是你的 DataFrame
# 示例结构：
# all_company_results = pd.DataFrame({
#     '公司简称': [...],
#     '股东': [...],
#     '净利润': [...],
#     '日期': [...],
#     '上市日期': [...]  # 每组的上市日期唯一
# })

def plot_net_profit_with_listing_date(all_company_results):
    # 确保 "日期" 和 "上市日期" 列为 datetime 类型
    all_company_results['日期'] = pd.to_datetime(all_company_results['日期'])
    all_company_results['上市日期'] = pd.to_datetime(all_company_results['上市日期'])

    # 按 '公司简称' 和 '股东' 分组
    grouped = all_company_results.groupby(['公司简称', '股东'])

    # 创建一个画布
    plt.figure(figsize=(16, 24))  # 图更宽一些

    # 遍历每个分组
    for (company, shareholder), group in grouped:
        # 根据日期排序
        group = group.sort_values('日期')
        
        # 绘制折线图
        plt.plot(group['日期'], group['净利润'], label=f"{company} - {shareholder}")
        
        # 找到唯一的上市日期及其对应的净利润值
        listing_date = group['上市日期'].iloc[0]
        if listing_date in group['日期'].values:
            net_profit_on_listing_date = group.loc[group['日期'] == listing_date, '净利润'].iloc[0]
            # 绘制点
            plt.scatter(listing_date, net_profit_on_listing_date, color='red', label=f"{company} - {shareholder} Listing Date")

    # 添加标题和标签
    plt.title("Net Profit by Date with Listing Dates Highlighted", fontsize=16)
    plt.xlabel("Date", fontsize=12)
    plt.ylabel("Net Profit", fontsize=12)

    # 添加图例并放在下方
    plt.legend(title="Company - Shareholder", fontsize=8, title_fontsize=10, loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)

    # 优化 x 轴日期显示
    plt.xticks(rotation=45)

    # 添加网格线
    plt.grid(visible=True, linestyle='--', alpha=0.5)

    # 显示图表
    plt.tight_layout()
    plt.show()

# 调用函数绘图
plot_net_profit_with_listing_date(all_company_results)

# %%
all_company_results[['退市风险警示']]
# Out:
#       退市风险警示
# 0
# 1
# 2
# 3
# 4
# ...      ...
# 56745
# 56746
# 56747
# 56748
# 56749
#
# [56750 rows x 1 columns]
